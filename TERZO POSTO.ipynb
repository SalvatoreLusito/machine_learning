# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import math
# Used to save logs on file
import sys
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from tensorflow.keras import layers
from tensorflow.keras import initializers
from tensorflow.keras import Sequential
# Used for L2 regularization
from tensorflow.keras import regularizers
# Used for dropout
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.optimizers import SGD, Adamax, RMSprop, Adagrad, Adam
from sklearn.model_selection import GridSearchCV
from keras.constraints import maxnorm
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.callbacks import ModelCheckpoint

from keras import backend as K

import tensorflow as tf


from datetime import datetime

# Used for early stopping
from tensorflow.keras.callbacks import EarlyStopping

from sklearn import preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Handling the dataset

# %%
# Read and view TR
# dataset = "cup/ML-CUP20-TR.csv"
dataset="/content/drive/My Drive/Machine Learning Project/CUP/data/ML-CUP20-TR.csv"

# Column 0:     ID
# Column 1-10:  inputs
# Column 11-12: target_x target_y
train_names = ["id", "input_1", "input_2", "input_3", "input_4", "input_5", "input_6", "input_7", "input_8", "input_9",
               "input_10", "target_x", "target_y"]
df_train = pd.DataFrame(pd.read_csv(dataset, sep=',', skiprows=7, header=None, names=train_names, index_col=0))

# Store the number of training patterns
n_TR_patterns = len(df_train.index)
print(f'N. rows TR: {n_TR_patterns}\n')

# log.write(f'N. rows TR: {n_TR_patterns}\n')

# print(df_train.head())

# Read and view TS
# dataset = "cup/ML-CUP20-TS.csv"
dataset="/content/drive/My Drive/Machine Learning Project/CUP/data/ML-CUP20-TS.csv"

# Column 0:    ID
# Column 1-10: inputs
test_names = ["id", "input_1", "input_2", "input_3", "input_4", "input_5", "input_6", "input_7", "input_8", "input_9",
              "input_10"]
df_test = pd.DataFrame(pd.read_csv(dataset, sep=',', skiprows=7, header=None, names=test_names, index_col=0))

# Store the number of (blind) testing patterns
n_TS_patterns = len(df_test.index)
print(f'N. rows TS: {n_TS_patterns}\n')

# log.write(f'N. rows TS: {n_TS_patterns}\n')

# print(df_test.head())
# Out:
# N. rows TR: 1524
#
# N. rows TS: 472

# %% [markdown]
# #DATA MANIPULATION

# %%
# Divide into TR and (internal) TS
attributes = [col for col in df_train.columns if 'input' in col]

# Separating internal TS from the rest of training dataset (ca. 20%)
print("\ndf_train ", len(df_train))  # 1524

df_subset = df_train.sample(200, random_state=100) #modifico la size del blind test set
print("\ndf_subset ", len(df_subset))  # 304
print(df_subset.head())

df_train = df_train.drop(df_subset.index)
print("\ndf_train after removal ", len(df_train))  # 1220

X_train = df_train[attributes].values
y_train = df_train[['target_x', 'target_y']].values

X_test = df_subset[attributes].values
y_test = df_subset[['target_x', 'target_y']].values

n_features = X_train.shape[1]
print(X_train.shape[0])

print(f'\nN. input features: {n_features}')

# log.write(f'\nN. input features: {n_features}')

# Handle (blind) TS
attributes = [col for col in df_test.columns if 'input' in col]
X_blind_TS = df_test[attributes].values
# Out:
# df_train  1524
#
# df_subset  200
#        input_1   input_2   input_3  ...  input_10   target_x   target_y
# id                                  ...
# 801   1.155300  0.059795 -0.604900  ...  1.727382  39.929663 -29.595517
# 720  -0.918605  0.637450  1.347002  ... -0.903759  72.384610 -28.855841
# 1059 -0.652593  1.394323  0.103282  ... -1.030427  52.796461 -39.445597
# 189   1.439956 -0.605409 -0.758339  ...  1.819379  40.553341 -30.551312
# 229   0.915644 -1.250489 -1.028318  ...  0.055362  31.467524 -13.706777
#
# [5 rows x 12 columns]
#
# df_train after removal  1324
# 1324
#
# N. input features: 10

# %% [markdown]
# # Building the network

# %%
def mee_keras(y_true, y_pred):
  return K.mean(K.sqrt(K.sum(K.square(y_true - y_pred), axis=-1, keepdims=True)))

# %%
def r2_keras(y_true, y_pred):
  SS_res = K.sum(K.square(y_true-y_pred))
  SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
  return (1 - SS_res/(SS_tot + K.epsilon()))

# %%
# Construction of the Neural Network
# Units input layer
# units_in = 6
# Units hidden layer
# units_hid = 4


def build_model(neurons=1, dropout_rate=0.0, weight_constraint=0, activation='sigmoid', learn_rate=0.001, momentum=0,
                reg_value=0, optimizer='adam', init_mode='uniform'):
    # Cleanup
    #K.clear_session()
    tf.keras.backend.clear_session()
    # Build the model
    model = Sequential()

    if reg_value != 0:
        # Apply regularization
        layer_1 = Dense(neurons, input_dim=n_features, activation=activation,
                        kernel_initializer=init_mode,
                        kernel_constraint=maxnorm(weight_constraint),
                        kernel_regularizer=regularizers.l2(reg_value),
                        bias_regularizer=regularizers.l2(reg_value))
        layer_2 = Dense(neurons, activation=activation,
                        kernel_initializer=init_mode,
                        kernel_constraint=maxnorm(weight_constraint),
                        kernel_regularizer=regularizers.l2(reg_value),
                        bias_regularizer=regularizers.l2(reg_value))
        layer_3 = Dense(2, activation='linear')
    else:
        # No regularization
        layer_1 = Dense(neurons, input_dim=n_features, activation=activation)
        layer_2 = Dense(neurons, activation=activation)
        layer_3 = Dense(2, activation=activation)

    model.add(layer_1)

    if dropout_rate != 0:
        # Add dropout, seed for reproducibility
        model.add(Dropout(dropout_rate, seed=123))

    model.add(layer_2)

    if dropout_rate != 0:
        # Add dropout, seed for reproducibility
        model.add(Dropout(dropout_rate, seed=123))

    model.add(layer_3)

    # Compile the model
    if optimizer == 'SGD':
      # opt = SGD(learning_rate=learn_rate, momentum=momentum)
      # With clipping
      opt = SGD(learning_rate=learn_rate, momentum=momentum, clipnorm=1.0)
    elif optimizer == 'Adamax':
      # opt = Adamax(learning_rate=learn_rate, name="Adamax")
      # With clipping
      opt = Adamax(learning_rate=learn_rate, name="Adamax", clipnorm=1.0)
    elif optimizer == 'RMSprop':
      # With clipping
      opt = RMSprop(learning_rate=learn_rate, rho=0.9, momentum=momentum, 
                    epsilon=1e-07, centered=False, name="RMSprop", clipnorm=1.0)
    elif optimizer == 'Adagrad':
      # With clipping
      opt = Adagrad(learning_rate=learn_rate, initial_accumulator_value=0.1,
                    epsilon=1e-07, name="Adagrad", clipnorm=1.0)
    else: 
      # Adam
      # With clipping
      opt = Adam(learning_rate=learn_rate, beta_1=0.9, beta_2=0.999, 
                 epsilon=1e-07, amsgrad=False, name="Adam", clipnorm=1.0)
    
    # Metrics: MSE, MEE (manual implementation), R^2 (manual implementation)
    model.compile(loss=MeanSquaredError(),
                  optimizer=opt,
                  # metrics=[tf.keras.metrics.MeanSquaredError()])
                  metrics=[tf.keras.metrics.MeanSquaredError(), mee_keras, 
                           r2_keras]) 

    return model

# %% [markdown]
# # Manual initialization

# %%
# Construction of the Neural Network
# Units input layer
# units_in = 6
# Units hidden layer
# units_hid = 4


def build_model(neurons=1, dropout_rate=0.0, weight_constraint=0, activation='sigmoid', learn_rate=0.001, momentum=0,
                reg_value=0, optimizer='adam', init_mode='uniform'):
    # Cleanup
    #K.clear_session()
    tf.keras.backend.clear_session()
    # Build the model
    model = Sequential()

    if reg_value != 0:
        # Apply regularization
        layer_1 = Dense(neurons, input_dim=n_features, activation=activation,
                        kernel_initializer=init_mode,
                        kernel_constraint=maxnorm(weight_constraint),
                        kernel_regularizer=regularizers.l2(reg_value),
                        bias_regularizer=regularizers.l2(reg_value))
        layer_2 = Dense(neurons, activation=activation,
                        kernel_initializer=init_mode,
                        kernel_constraint=maxnorm(weight_constraint),
                        kernel_regularizer=regularizers.l2(reg_value),
                        bias_regularizer=regularizers.l2(reg_value))
        layer_3 = Dense(2, activation='linear')
    else:
        # No regularization
        layer_1 = Dense(neurons, input_dim=n_features, activation=activation)
        layer_2 = Dense(neurons, activation=activation)
        layer_3 = Dense(2, activation=activation)

    model.add(layer_1)

    if dropout_rate != 0:
        # Add dropout, seed for reproducibility
        model.add(Dropout(dropout_rate, seed=123))

    model.add(layer_2)

    if dropout_rate != 0:
        # Add dropout, seed for reproducibility
        model.add(Dropout(dropout_rate, seed=123))

    model.add(layer_3)

    # Compile the model
    if optimizer == 'SGD':
      # opt = SGD(learning_rate=learn_rate, momentum=momentum)
      # With clipping
      opt = SGD(learning_rate=learn_rate, momentum=momentum, clipnorm=1.0)
    elif optimizer == 'Adamax':
      # opt = Adamax(learning_rate=learn_rate, name="Adamax")
      # With clipping
      opt = Adamax(learning_rate=learn_rate, name="Adamax", clipnorm=1.0)
    elif optimizer == 'RMSprop':
      # With clipping
      opt = RMSprop(learning_rate=learn_rate, rho=0.9, momentum=momentum, 
                    epsilon=1e-07, centered=False, name="RMSprop", clipnorm=1.0)
    elif optimizer == 'Adagrad':
      # With clipping
      opt = Adagrad(learning_rate=learn_rate, initial_accumulator_value=0.1,
                    epsilon=1e-07, name="Adagrad", clipnorm=1.0)
    else: 
      # Adam
      # With clipping
      opt = Adam(learning_rate=learn_rate, beta_1=0.9, beta_2=0.999, 
                 epsilon=1e-07, amsgrad=False, name="Adam", clipnorm=1.0)
    
    # Metrics: MSE, MEE (manual implementation), R^2 (manual implementation)
    model.compile(loss=MeanSquaredError(),
                  optimizer=opt,
                  # metrics=[tf.keras.metrics.MeanSquaredError()])
                  metrics=[tf.keras.metrics.MeanSquaredError(), mee_keras, 
                           r2_keras]) 

    return model

# %%
def init_config(units_hid = 10, r = 1/math.sqrt(n_features)):
  config_hid1 = []
  config_hid2 = []
  config_hid3 = []
  # config_hid4 = []
  # config_hid5 = []

  # weights_in = np.random.uniform(-0.2, 0.2, size=(n_features,units_hid))
  weights_in = np.random.uniform(-r, r, size=(n_features,units_hid))
  # bias_in = np.random.uniform(-0.2, 0.2, units_hid)
  if r == 1/math.sqrt(n_features):
    bias_in = np.zeros(units_hid)
  else:
    bias_in = np.random.uniform(-r, r, units_hid)
  config_hid1.append(weights_in)
  config_hid1.append(bias_in)

  # weights_in = np.random.uniform(-0.2, 0.2, size=(n_features,units_hid))
  weights_in = np.random.uniform(-r, r, size=(units_hid,units_hid))
  # bias_in = np.random.uniform(-0.2, 0.2, units_hid)
  if r == 1/math.sqrt(n_features):
    bias_in = np.zeros(units_hid)
  else:
    bias_in = np.random.uniform(-r, r, units_hid)
  config_hid2.append(weights_in)
  config_hid2.append(bias_in)

  # weights_hid = np.random.uniform(-0.3, 0.3, size=(units_hid,1))
  weights_in = np.random.uniform(-r, r, size=(units_hid,2))
  # bias_hid = np.random.uniform(-0.2, 0.2, 1)
  if r == 1/math.sqrt(n_features):
    bias_in = np.zeros(2)
  else:
    bias_in = np.random.uniform(-r, r, 2)
  config_hid3.append(weights_in)
  config_hid3.append(bias_in)

  # return [config_hid1, config_hid2, config_hid3, config_hid4, config_hid5]
  return [config_hid1, config_hid2, config_hid3]

# %%
early_val_loss = EarlyStopping(
    monitor="val_loss",
    min_delta=0.01,
    patience=100,
    mode="min",
    restore_best_weights=True,
)

early_val_accuracy = EarlyStopping(
    monitor="val_r2_keras",
    patience=100,
    mode="max",
    restore_best_weights=True,
)

# %%
# Current best model
n_neurons = 300
model = build_model(neurons=n_neurons, dropout_rate=0.0, weight_constraint=1, activation='tanh', learn_rate=0.1, momentum=0.1, reg_value=0.01, optimizer='SGD', init_mode='he_uniform')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 300)               3300
# _________________________________________________________________
# dense_1 (Dense)              (None, 300)               90300
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 602
# =================================================================
# Total params: 94,202
# Trainable params: 94,202
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #CROSS VALIDATION

# %%
from sklearn.model_selection import KFold

num_folds = 20
batch_size=50

min_mee = 100

# Define per-fold score containers
mse_per_fold = []
mee_per_fold = []
r2_per_fold = []
loss_per_fold = []

val_mse_per_fold = []
val_mee_per_fold = []
val_r2_per_fold = []
val_loss_per_fold = []


list_of_history = []

# Merge inputs and targets
inputs = np.concatenate((X_train, X_test), axis=0)
targets = np.concatenate((y_train, y_test), axis=0)

# Define the K-fold Cross Validator
kfold = KFold(n_splits=num_folds, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train, y_train):
  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')

  # Fit data to model
  history = model.fit(inputs[train], targets[train],
              batch_size=batch_size, validation_split=0.33,
              epochs=500, 
              callbacks=[early_val_accuracy, early_val_loss] 
              )

  # Generate generalization metrics
  scores = model.evaluate(inputs[test], targets[test], verbose=0)

  #compare mee value on fold test set to select the best submodel
  if min_mee > scores[2]:
    min_mee = scores[2]
    submodel = model
    best_fold = fold_no
  
  loss_per_fold.append(scores[0])
  mse_per_fold.append(scores[1])
  mee_per_fold.append(scores[2])
  r2_per_fold.append(scores[3])

  list_of_history.append(history)

  # Increase fold number
  fold_no = fold_no + 1
# Out:
# Output streaming troncato alle ultime 5000 righe.
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5344 - mean_squared_error: 5.0051 - mee_keras: 2.4727 - r2_keras: 0.9969 - val_loss: 10.9350 - val_mean_squared_error: 8.3996 - val_mee_keras: 3.0136 - val_r2_keras: 0.9951
# Epoch 264/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.4435 - mean_squared_error: 4.9191 - mee_keras: 2.4132 - r2_keras: 0.9970 - val_loss: 10.3374 - val_mean_squared_error: 7.8213 - val_mee_keras: 3.0747 - val_r2_keras: 0.9954
# Epoch 265/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5988 - mean_squared_error: 5.0781 - mee_keras: 2.4523 - r2_keras: 0.9969 - val_loss: 10.5735 - val_mean_squared_error: 8.0560 - val_mee_keras: 3.1058 - val_r2_keras: 0.9953
# Epoch 266/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.3111 - mean_squared_error: 4.7889 - mee_keras: 2.4134 - r2_keras: 0.9971 - val_loss: 11.5838 - val_mean_squared_error: 9.0676 - val_mee_keras: 3.2154 - val_r2_keras: 0.9947
# Epoch 267/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5571 - mean_squared_error: 5.0382 - mee_keras: 2.4564 - r2_keras: 0.9969 - val_loss: 10.0867 - val_mean_squared_error: 7.5658 - val_mee_keras: 2.9206 - val_r2_keras: 0.9956
# Epoch 268/500
# 17/17 [==============================] - 0s 8ms/step - loss: 7.1434 - mean_squared_error: 4.6295 - mee_keras: 2.3654 - r2_keras: 0.9971 - val_loss: 10.3340 - val_mean_squared_error: 7.8196 - val_mee_keras: 2.9819 - val_r2_keras: 0.9954
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/500
# 17/17 [==============================] - 0s 23ms/step - loss: 8.7671 - mean_squared_error: 5.7005 - mee_keras: 2.5773 - r2_keras: 0.9965 - val_loss: 10.5036 - val_mean_squared_error: 7.4378 - val_mee_keras: 2.9196 - val_r2_keras: 0.9954
# Epoch 2/500
# 17/17 [==============================] - 0s 6ms/step - loss: 8.7022 - mean_squared_error: 5.6484 - mee_keras: 2.6035 - r2_keras: 0.9965 - val_loss: 10.9612 - val_mean_squared_error: 7.9133 - val_mee_keras: 3.1366 - val_r2_keras: 0.9952
# Epoch 3/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.5769 - mean_squared_error: 5.5326 - mee_keras: 2.5273 - r2_keras: 0.9966 - val_loss: 10.9228 - val_mean_squared_error: 7.8897 - val_mee_keras: 3.0134 - val_r2_keras: 0.9953
# Epoch 4/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.7650 - mean_squared_error: 5.7368 - mee_keras: 2.5789 - r2_keras: 0.9964 - val_loss: 11.1004 - val_mean_squared_error: 8.0857 - val_mee_keras: 3.0697 - val_r2_keras: 0.9952
# Epoch 5/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.3679 - mean_squared_error: 5.3568 - mee_keras: 2.5257 - r2_keras: 0.9967 - val_loss: 10.5388 - val_mean_squared_error: 7.5421 - val_mee_keras: 3.1153 - val_r2_keras: 0.9955
# Epoch 6/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.7968 - mean_squared_error: 5.8029 - mee_keras: 2.6040 - r2_keras: 0.9965 - val_loss: 10.7123 - val_mean_squared_error: 7.7148 - val_mee_keras: 2.9395 - val_r2_keras: 0.9953
# Epoch 7/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.5849 - mean_squared_error: 5.6001 - mee_keras: 2.5144 - r2_keras: 0.9966 - val_loss: 11.4658 - val_mean_squared_error: 8.4930 - val_mee_keras: 3.3152 - val_r2_keras: 0.9948
# Epoch 8/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.9840 - mean_squared_error: 6.0090 - mee_keras: 2.6177 - r2_keras: 0.9963 - val_loss: 10.4047 - val_mean_squared_error: 7.4298 - val_mee_keras: 2.9730 - val_r2_keras: 0.9955
# Epoch 9/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4121 - mean_squared_error: 5.4472 - mee_keras: 2.5305 - r2_keras: 0.9966 - val_loss: 10.3326 - val_mean_squared_error: 7.3732 - val_mee_keras: 2.9583 - val_r2_keras: 0.9955
# Epoch 10/500
# 17/17 [==============================] - 0s 6ms/step - loss: 8.6558 - mean_squared_error: 5.7020 - mee_keras: 2.5966 - r2_keras: 0.9965 - val_loss: 11.8072 - val_mean_squared_error: 8.8539 - val_mee_keras: 3.2518 - val_r2_keras: 0.9946
# Epoch 11/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.5383 - mean_squared_error: 5.5912 - mee_keras: 2.5374 - r2_keras: 0.9966 - val_loss: 10.4087 - val_mean_squared_error: 7.4696 - val_mee_keras: 3.0625 - val_r2_keras: 0.9955
# Epoch 12/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.5317 - mean_squared_error: 5.5924 - mee_keras: 2.5210 - r2_keras: 0.9966 - val_loss: 10.6268 - val_mean_squared_error: 7.6943 - val_mee_keras: 3.0205 - val_r2_keras: 0.9954
# Epoch 13/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.7216 - mean_squared_error: 5.7871 - mee_keras: 2.5920 - r2_keras: 0.9965 - val_loss: 11.3036 - val_mean_squared_error: 8.3686 - val_mee_keras: 3.0412 - val_r2_keras: 0.9948
# Epoch 14/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.5071 - mean_squared_error: 5.5795 - mee_keras: 2.5664 - r2_keras: 0.9966 - val_loss: 10.6458 - val_mean_squared_error: 7.7099 - val_mee_keras: 2.9851 - val_r2_keras: 0.9954
# Epoch 15/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.8860 - mean_squared_error: 5.9578 - mee_keras: 2.6027 - r2_keras: 0.9963 - val_loss: 10.0138 - val_mean_squared_error: 7.0853 - val_mee_keras: 2.8923 - val_r2_keras: 0.9957
# Epoch 16/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4401 - mean_squared_error: 5.5193 - mee_keras: 2.5553 - r2_keras: 0.9966 - val_loss: 10.8211 - val_mean_squared_error: 7.9069 - val_mee_keras: 2.9848 - val_r2_keras: 0.9953
# Epoch 17/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.6174 - mean_squared_error: 5.7050 - mee_keras: 2.5808 - r2_keras: 0.9965 - val_loss: 10.9687 - val_mean_squared_error: 8.0669 - val_mee_keras: 3.0129 - val_r2_keras: 0.9952
# Epoch 18/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2653 - mean_squared_error: 5.3603 - mee_keras: 2.4964 - r2_keras: 0.9967 - val_loss: 10.4582 - val_mean_squared_error: 7.5508 - val_mee_keras: 2.9581 - val_r2_keras: 0.9954
# Epoch 19/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1265 - mean_squared_error: 5.2316 - mee_keras: 2.5135 - r2_keras: 0.9968 - val_loss: 10.8389 - val_mean_squared_error: 7.9437 - val_mee_keras: 3.0852 - val_r2_keras: 0.9951
# Epoch 20/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.7554 - mean_squared_error: 5.8635 - mee_keras: 2.6330 - r2_keras: 0.9964 - val_loss: 9.9997 - val_mean_squared_error: 7.1077 - val_mee_keras: 2.8542 - val_r2_keras: 0.9957
# Epoch 21/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4592 - mean_squared_error: 5.5739 - mee_keras: 2.5217 - r2_keras: 0.9966 - val_loss: 10.6076 - val_mean_squared_error: 7.7171 - val_mee_keras: 2.9596 - val_r2_keras: 0.9952
# Epoch 22/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.6143 - mean_squared_error: 5.7342 - mee_keras: 2.5619 - r2_keras: 0.9965 - val_loss: 10.3910 - val_mean_squared_error: 7.5098 - val_mee_keras: 2.8724 - val_r2_keras: 0.9954
# Epoch 23/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.3848 - mean_squared_error: 5.5090 - mee_keras: 2.5333 - r2_keras: 0.9966 - val_loss: 11.5498 - val_mean_squared_error: 8.6680 - val_mee_keras: 3.1438 - val_r2_keras: 0.9947
# Epoch 24/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.8221 - mean_squared_error: 5.9546 - mee_keras: 2.6309 - r2_keras: 0.9964 - val_loss: 10.5689 - val_mean_squared_error: 7.7001 - val_mee_keras: 2.9583 - val_r2_keras: 0.9953
# Epoch 25/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4670 - mean_squared_error: 5.6095 - mee_keras: 2.5593 - r2_keras: 0.9966 - val_loss: 10.5580 - val_mean_squared_error: 7.7022 - val_mee_keras: 2.9512 - val_r2_keras: 0.9953
# Epoch 26/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.3362 - mean_squared_error: 5.4878 - mee_keras: 2.5579 - r2_keras: 0.9966 - val_loss: 10.2099 - val_mean_squared_error: 7.3713 - val_mee_keras: 2.9863 - val_r2_keras: 0.9955
# Epoch 27/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.1116 - mean_squared_error: 5.2750 - mee_keras: 2.4985 - r2_keras: 0.9968 - val_loss: 11.0547 - val_mean_squared_error: 8.2186 - val_mee_keras: 3.1049 - val_r2_keras: 0.9950
# Epoch 28/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.0648 - mean_squared_error: 5.2360 - mee_keras: 2.4813 - r2_keras: 0.9968 - val_loss: 11.6635 - val_mean_squared_error: 8.8311 - val_mee_keras: 3.3765 - val_r2_keras: 0.9948
# Epoch 29/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.3280 - mean_squared_error: 5.5036 - mee_keras: 2.5347 - r2_keras: 0.9966 - val_loss: 10.9645 - val_mean_squared_error: 8.1451 - val_mee_keras: 3.2024 - val_r2_keras: 0.9952
# Epoch 30/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2990 - mean_squared_error: 5.4856 - mee_keras: 2.5338 - r2_keras: 0.9967 - val_loss: 11.0440 - val_mean_squared_error: 8.2237 - val_mee_keras: 3.0198 - val_r2_keras: 0.9949
# Epoch 31/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2229 - mean_squared_error: 5.4125 - mee_keras: 2.5085 - r2_keras: 0.9967 - val_loss: 11.5418 - val_mean_squared_error: 8.7446 - val_mee_keras: 3.1502 - val_r2_keras: 0.9948
# Epoch 32/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.3231 - mean_squared_error: 5.5222 - mee_keras: 2.5163 - r2_keras: 0.9966 - val_loss: 10.1302 - val_mean_squared_error: 7.3339 - val_mee_keras: 2.9451 - val_r2_keras: 0.9955
# Epoch 33/500
# 17/17 [==============================] - 0s 6ms/step - loss: 8.1129 - mean_squared_error: 5.3163 - mee_keras: 2.4737 - r2_keras: 0.9968 - val_loss: 10.5123 - val_mean_squared_error: 7.7178 - val_mee_keras: 3.0566 - val_r2_keras: 0.9953
# Epoch 34/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2061 - mean_squared_error: 5.4138 - mee_keras: 2.5541 - r2_keras: 0.9967 - val_loss: 12.0156 - val_mean_squared_error: 9.2366 - val_mee_keras: 3.2580 - val_r2_keras: 0.9945
# Epoch 35/500
# 17/17 [==============================] - 0s 6ms/step - loss: 8.0697 - mean_squared_error: 5.2883 - mee_keras: 2.5122 - r2_keras: 0.9968 - val_loss: 10.0655 - val_mean_squared_error: 7.2912 - val_mee_keras: 2.9535 - val_r2_keras: 0.9956
# Epoch 36/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.0197 - mean_squared_error: 5.2476 - mee_keras: 2.5001 - r2_keras: 0.9968 - val_loss: 10.7675 - val_mean_squared_error: 7.9930 - val_mee_keras: 3.0200 - val_r2_keras: 0.9951
# Epoch 37/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1163 - mean_squared_error: 5.3511 - mee_keras: 2.5094 - r2_keras: 0.9967 - val_loss: 10.4716 - val_mean_squared_error: 7.7091 - val_mee_keras: 2.9633 - val_r2_keras: 0.9953
# Epoch 38/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1412 - mean_squared_error: 5.3887 - mee_keras: 2.5604 - r2_keras: 0.9967 - val_loss: 10.1233 - val_mean_squared_error: 7.3776 - val_mee_keras: 2.9268 - val_r2_keras: 0.9954
# Epoch 39/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9850 - mean_squared_error: 5.2397 - mee_keras: 2.4843 - r2_keras: 0.9968 - val_loss: 10.0551 - val_mean_squared_error: 7.3076 - val_mee_keras: 2.9163 - val_r2_keras: 0.9955
# Epoch 40/500
# 17/17 [==============================] - 0s 6ms/step - loss: 8.2936 - mean_squared_error: 5.5465 - mee_keras: 2.5618 - r2_keras: 0.9966 - val_loss: 9.9778 - val_mean_squared_error: 7.2361 - val_mee_keras: 2.9684 - val_r2_keras: 0.9957
# Epoch 41/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2559 - mean_squared_error: 5.5108 - mee_keras: 2.5369 - r2_keras: 0.9966 - val_loss: 10.3818 - val_mean_squared_error: 7.6442 - val_mee_keras: 3.0764 - val_r2_keras: 0.9954
# Epoch 42/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.0702 - mean_squared_error: 5.3350 - mee_keras: 2.5019 - r2_keras: 0.9967 - val_loss: 10.3847 - val_mean_squared_error: 7.6564 - val_mee_keras: 3.0197 - val_r2_keras: 0.9954
# Epoch 43/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1554 - mean_squared_error: 5.4296 - mee_keras: 2.5313 - r2_keras: 0.9967 - val_loss: 10.1830 - val_mean_squared_error: 7.4594 - val_mee_keras: 2.9241 - val_r2_keras: 0.9954
# Epoch 44/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1067 - mean_squared_error: 5.3825 - mee_keras: 2.5149 - r2_keras: 0.9967 - val_loss: 11.4353 - val_mean_squared_error: 8.7138 - val_mee_keras: 3.2870 - val_r2_keras: 0.9948
# Epoch 45/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.0686 - mean_squared_error: 5.3466 - mee_keras: 2.4901 - r2_keras: 0.9967 - val_loss: 10.3588 - val_mean_squared_error: 7.6486 - val_mee_keras: 3.1143 - val_r2_keras: 0.9954
# Epoch 46/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.0508 - mean_squared_error: 5.3416 - mee_keras: 2.4822 - r2_keras: 0.9968 - val_loss: 10.2324 - val_mean_squared_error: 7.5209 - val_mee_keras: 2.9538 - val_r2_keras: 0.9954
# Epoch 47/500
# 17/17 [==============================] - 0s 8ms/step - loss: 7.9784 - mean_squared_error: 5.2742 - mee_keras: 2.4915 - r2_keras: 0.9968 - val_loss: 10.3461 - val_mean_squared_error: 7.6420 - val_mee_keras: 3.0138 - val_r2_keras: 0.9954
# Epoch 48/500
# 17/17 [==============================] - 0s 6ms/step - loss: 7.9383 - mean_squared_error: 5.2416 - mee_keras: 2.5095 - r2_keras: 0.9968 - val_loss: 10.1779 - val_mean_squared_error: 7.4808 - val_mee_keras: 2.9539 - val_r2_keras: 0.9954
# Epoch 49/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.0527 - mean_squared_error: 5.3573 - mee_keras: 2.5233 - r2_keras: 0.9967 - val_loss: 10.5334 - val_mean_squared_error: 7.8382 - val_mee_keras: 3.0187 - val_r2_keras: 0.9952
# Epoch 50/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1083 - mean_squared_error: 5.4145 - mee_keras: 2.5455 - r2_keras: 0.9967 - val_loss: 10.0914 - val_mean_squared_error: 7.3941 - val_mee_keras: 2.9716 - val_r2_keras: 0.9956
# Epoch 51/500
# 17/17 [==============================] - 0s 8ms/step - loss: 7.9500 - mean_squared_error: 5.2596 - mee_keras: 2.4713 - r2_keras: 0.9968 - val_loss: 10.1531 - val_mean_squared_error: 7.4632 - val_mee_keras: 2.9747 - val_r2_keras: 0.9954
# Epoch 52/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8690 - mean_squared_error: 5.1830 - mee_keras: 2.4694 - r2_keras: 0.9968 - val_loss: 11.0226 - val_mean_squared_error: 8.3342 - val_mee_keras: 3.1725 - val_r2_keras: 0.9950
# Epoch 53/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8888 - mean_squared_error: 5.2093 - mee_keras: 2.4723 - r2_keras: 0.9968 - val_loss: 12.1647 - val_mean_squared_error: 9.4914 - val_mee_keras: 3.4302 - val_r2_keras: 0.9944
# Epoch 54/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9494 - mean_squared_error: 5.2717 - mee_keras: 2.4935 - r2_keras: 0.9968 - val_loss: 11.4479 - val_mean_squared_error: 8.7750 - val_mee_keras: 3.2023 - val_r2_keras: 0.9948
# Epoch 55/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9099 - mean_squared_error: 5.2364 - mee_keras: 2.4872 - r2_keras: 0.9968 - val_loss: 10.8137 - val_mean_squared_error: 8.1400 - val_mee_keras: 3.0195 - val_r2_keras: 0.9949
# Epoch 56/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9684 - mean_squared_error: 5.3019 - mee_keras: 2.5019 - r2_keras: 0.9968 - val_loss: 10.5495 - val_mean_squared_error: 7.8848 - val_mee_keras: 2.9682 - val_r2_keras: 0.9950
# Epoch 57/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.7513 - mean_squared_error: 5.0888 - mee_keras: 2.4208 - r2_keras: 0.9969 - val_loss: 10.7686 - val_mean_squared_error: 8.1139 - val_mee_keras: 3.1827 - val_r2_keras: 0.9951
# Epoch 58/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9724 - mean_squared_error: 5.3207 - mee_keras: 2.5294 - r2_keras: 0.9968 - val_loss: 10.4874 - val_mean_squared_error: 7.8349 - val_mee_keras: 2.9852 - val_r2_keras: 0.9952
# Epoch 59/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1889 - mean_squared_error: 5.5452 - mee_keras: 2.5095 - r2_keras: 0.9966 - val_loss: 10.8656 - val_mean_squared_error: 8.2188 - val_mee_keras: 3.0511 - val_r2_keras: 0.9948
# Epoch 60/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9103 - mean_squared_error: 5.2721 - mee_keras: 2.5234 - r2_keras: 0.9968 - val_loss: 10.2614 - val_mean_squared_error: 7.6339 - val_mee_keras: 3.0314 - val_r2_keras: 0.9954
# Epoch 61/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8592 - mean_squared_error: 5.2307 - mee_keras: 2.4749 - r2_keras: 0.9968 - val_loss: 10.1975 - val_mean_squared_error: 7.5635 - val_mee_keras: 2.8964 - val_r2_keras: 0.9953
# Epoch 62/500
# 17/17 [==============================] - 0s 6ms/step - loss: 7.9777 - mean_squared_error: 5.3489 - mee_keras: 2.5066 - r2_keras: 0.9967 - val_loss: 10.4579 - val_mean_squared_error: 7.8336 - val_mee_keras: 3.0570 - val_r2_keras: 0.9953
# Epoch 63/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9202 - mean_squared_error: 5.2942 - mee_keras: 2.5081 - r2_keras: 0.9968 - val_loss: 9.9155 - val_mean_squared_error: 7.2924 - val_mee_keras: 2.8930 - val_r2_keras: 0.9955
# Epoch 64/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.7186 - mean_squared_error: 5.1036 - mee_keras: 2.4397 - r2_keras: 0.9969 - val_loss: 10.9442 - val_mean_squared_error: 8.3405 - val_mee_keras: 3.2387 - val_r2_keras: 0.9950
# Epoch 65/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9840 - mean_squared_error: 5.3777 - mee_keras: 2.5348 - r2_keras: 0.9966 - val_loss: 10.1398 - val_mean_squared_error: 7.5387 - val_mee_keras: 2.9661 - val_r2_keras: 0.9954
# Epoch 66/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8333 - mean_squared_error: 5.2322 - mee_keras: 2.5532 - r2_keras: 0.9968 - val_loss: 11.3546 - val_mean_squared_error: 8.7458 - val_mee_keras: 3.1154 - val_r2_keras: 0.9945
# Epoch 67/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8690 - mean_squared_error: 5.2684 - mee_keras: 2.4981 - r2_keras: 0.9968 - val_loss: 10.5756 - val_mean_squared_error: 7.9800 - val_mee_keras: 3.0822 - val_r2_keras: 0.9952
# Epoch 68/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8448 - mean_squared_error: 5.2470 - mee_keras: 2.4474 - r2_keras: 0.9968 - val_loss: 10.9599 - val_mean_squared_error: 8.3634 - val_mee_keras: 3.1804 - val_r2_keras: 0.9950
# Epoch 69/500
# 17/17 [==============================] - 0s 6ms/step - loss: 7.8960 - mean_squared_error: 5.3080 - mee_keras: 2.5343 - r2_keras: 0.9968 - val_loss: 10.1328 - val_mean_squared_error: 7.5475 - val_mee_keras: 2.9675 - val_r2_keras: 0.9954
# Epoch 70/500
# 17/17 [==============================] - 0s 6ms/step - loss: 8.1310 - mean_squared_error: 5.5523 - mee_keras: 2.5195 - r2_keras: 0.9966 - val_loss: 12.3644 - val_mean_squared_error: 9.7817 - val_mee_keras: 3.4337 - val_r2_keras: 0.9940
# Epoch 71/500
# 17/17 [==============================] - 0s 6ms/step - loss: 7.6162 - mean_squared_error: 5.0396 - mee_keras: 2.4756 - r2_keras: 0.9969 - val_loss: 10.5547 - val_mean_squared_error: 7.9706 - val_mee_keras: 2.9810 - val_r2_keras: 0.9950
# Epoch 72/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.6659 - mean_squared_error: 5.0891 - mee_keras: 2.4495 - r2_keras: 0.9969 - val_loss: 11.6994 - val_mean_squared_error: 9.1185 - val_mee_keras: 3.1837 - val_r2_keras: 0.9943
# Epoch 73/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8281 - mean_squared_error: 5.2556 - mee_keras: 2.5191 - r2_keras: 0.9968 - val_loss: 12.0357 - val_mean_squared_error: 9.4723 - val_mee_keras: 3.3969 - val_r2_keras: 0.9944
# Epoch 74/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8738 - mean_squared_error: 5.3005 - mee_keras: 2.4694 - r2_keras: 0.9968 - val_loss: 10.4245 - val_mean_squared_error: 7.8599 - val_mee_keras: 3.1095 - val_r2_keras: 0.9953
# Epoch 75/500
# 17/17 [==============================] - 0s 8ms/step - loss: 7.8708 - mean_squared_error: 5.3008 - mee_keras: 2.4818 - r2_keras: 0.9968 - val_loss: 10.0484 - val_mean_squared_error: 7.4853 - val_mee_keras: 2.9340 - val_r2_keras: 0.9955
# Epoch 76/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.0574 - mean_squared_error: 5.4937 - mee_keras: 2.5456 - r2_keras: 0.9967 - val_loss: 11.2267 - val_mean_squared_error: 8.6580 - val_mee_keras: 3.1516 - val_r2_keras: 0.9947
# Epoch 77/500
# 17/17 [==============================] - 0s 6ms/step - loss: 7.8135 - mean_squared_error: 5.2553 - mee_keras: 2.4493 - r2_keras: 0.9968 - val_loss: 10.4523 - val_mean_squared_error: 7.8936 - val_mee_keras: 3.0486 - val_r2_keras: 0.9951
# Epoch 78/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5670 - mean_squared_error: 5.0125 - mee_keras: 2.4952 - r2_keras: 0.9969 - val_loss: 10.5384 - val_mean_squared_error: 7.9834 - val_mee_keras: 3.0602 - val_r2_keras: 0.9951
# Epoch 79/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.0292 - mean_squared_error: 5.4798 - mee_keras: 2.5357 - r2_keras: 0.9966 - val_loss: 11.0959 - val_mean_squared_error: 8.5507 - val_mee_keras: 3.1861 - val_r2_keras: 0.9949
# Epoch 80/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.6402 - mean_squared_error: 5.0933 - mee_keras: 2.4399 - r2_keras: 0.9969 - val_loss: 10.5738 - val_mean_squared_error: 8.0189 - val_mee_keras: 3.1209 - val_r2_keras: 0.9951
# Epoch 81/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.6005 - mean_squared_error: 5.0568 - mee_keras: 2.4025 - r2_keras: 0.9969 - val_loss: 11.1847 - val_mean_squared_error: 8.6506 - val_mee_keras: 3.2071 - val_r2_keras: 0.9948
# Epoch 82/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.6052 - mean_squared_error: 5.0660 - mee_keras: 2.4647 - r2_keras: 0.9969 - val_loss: 10.3765 - val_mean_squared_error: 7.8462 - val_mee_keras: 3.1247 - val_r2_keras: 0.9952
# Epoch 83/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9383 - mean_squared_error: 5.4024 - mee_keras: 2.5202 - r2_keras: 0.9967 - val_loss: 11.0723 - val_mean_squared_error: 8.5385 - val_mee_keras: 3.2578 - val_r2_keras: 0.9947
# Epoch 84/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.7274 - mean_squared_error: 5.1901 - mee_keras: 2.4969 - r2_keras: 0.9969 - val_loss: 10.4540 - val_mean_squared_error: 7.9198 - val_mee_keras: 3.0784 - val_r2_keras: 0.9953
# Epoch 85/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.6412 - mean_squared_error: 5.1049 - mee_keras: 2.4170 - r2_keras: 0.9969 - val_loss: 10.9888 - val_mean_squared_error: 8.4569 - val_mee_keras: 3.1334 - val_r2_keras: 0.9949
# Epoch 86/500
# 17/17 [==============================] - 0s 6ms/step - loss: 7.6552 - mean_squared_error: 5.1241 - mee_keras: 2.4415 - r2_keras: 0.9969 - val_loss: 12.8290 - val_mean_squared_error: 10.2952 - val_mee_keras: 3.5010 - val_r2_keras: 0.9936
# Epoch 87/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.6580 - mean_squared_error: 5.1321 - mee_keras: 2.4485 - r2_keras: 0.9969 - val_loss: 10.1039 - val_mean_squared_error: 7.5764 - val_mee_keras: 3.0117 - val_r2_keras: 0.9954
# Epoch 88/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.3498 - mean_squared_error: 4.8323 - mee_keras: 2.4104 - r2_keras: 0.9971 - val_loss: 11.1546 - val_mean_squared_error: 8.6359 - val_mee_keras: 3.2853 - val_r2_keras: 0.9946
# Epoch 89/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5086 - mean_squared_error: 4.9955 - mee_keras: 2.4181 - r2_keras: 0.9969 - val_loss: 10.7146 - val_mean_squared_error: 8.1958 - val_mee_keras: 3.0827 - val_r2_keras: 0.9950
# Epoch 90/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5307 - mean_squared_error: 5.0212 - mee_keras: 2.4252 - r2_keras: 0.9969 - val_loss: 10.0307 - val_mean_squared_error: 7.5174 - val_mee_keras: 2.8819 - val_r2_keras: 0.9954
# Epoch 91/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5998 - mean_squared_error: 5.0888 - mee_keras: 2.4533 - r2_keras: 0.9968 - val_loss: 10.5397 - val_mean_squared_error: 8.0372 - val_mee_keras: 3.1392 - val_r2_keras: 0.9950
# Epoch 92/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5222 - mean_squared_error: 5.0194 - mee_keras: 2.4435 - r2_keras: 0.9969 - val_loss: 10.6345 - val_mean_squared_error: 8.1383 - val_mee_keras: 3.0870 - val_r2_keras: 0.9951
# Epoch 93/500
# 17/17 [==============================] - 0s 6ms/step - loss: 7.5119 - mean_squared_error: 5.0131 - mee_keras: 2.4387 - r2_keras: 0.9969 - val_loss: 10.3476 - val_mean_squared_error: 7.8390 - val_mee_keras: 3.0289 - val_r2_keras: 0.9953
# Epoch 94/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8114 - mean_squared_error: 5.3098 - mee_keras: 2.5448 - r2_keras: 0.9968 - val_loss: 10.2413 - val_mean_squared_error: 7.7403 - val_mee_keras: 3.0312 - val_r2_keras: 0.9954
# Epoch 95/500
# 17/17 [==============================] - 0s 6ms/step - loss: 7.3499 - mean_squared_error: 4.8488 - mee_keras: 2.3856 - r2_keras: 0.9970 - val_loss: 10.2056 - val_mean_squared_error: 7.7050 - val_mee_keras: 3.0239 - val_r2_keras: 0.9952
# Epoch 96/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.7431 - mean_squared_error: 5.2451 - mee_keras: 2.4779 - r2_keras: 0.9968 - val_loss: 9.9743 - val_mean_squared_error: 7.4702 - val_mee_keras: 2.9600 - val_r2_keras: 0.9954
# Epoch 97/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.7519 - mean_squared_error: 5.2498 - mee_keras: 2.4497 - r2_keras: 0.9968 - val_loss: 10.5652 - val_mean_squared_error: 8.0604 - val_mee_keras: 3.0015 - val_r2_keras: 0.9949
# Epoch 98/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5179 - mean_squared_error: 5.0162 - mee_keras: 2.4478 - r2_keras: 0.9969 - val_loss: 10.0431 - val_mean_squared_error: 7.5426 - val_mee_keras: 2.9405 - val_r2_keras: 0.9953
# Epoch 99/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.0525 - mean_squared_error: 5.5584 - mee_keras: 2.5165 - r2_keras: 0.9966 - val_loss: 10.7779 - val_mean_squared_error: 8.2789 - val_mee_keras: 3.0488 - val_r2_keras: 0.9948
# Epoch 100/500
# 17/17 [==============================] - 0s 6ms/step - loss: 7.6150 - mean_squared_error: 5.1203 - mee_keras: 2.5058 - r2_keras: 0.9969 - val_loss: 10.9845 - val_mean_squared_error: 8.5002 - val_mee_keras: 3.2382 - val_r2_keras: 0.9948
# Epoch 101/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.6465 - mean_squared_error: 5.1579 - mee_keras: 2.4999 - r2_keras: 0.9968 - val_loss: 10.1449 - val_mean_squared_error: 7.6620 - val_mee_keras: 3.0861 - val_r2_keras: 0.9953
# Epoch 102/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8029 - mean_squared_error: 5.3195 - mee_keras: 2.4984 - r2_keras: 0.9967 - val_loss: 11.2522 - val_mean_squared_error: 8.7706 - val_mee_keras: 3.2277 - val_r2_keras: 0.9948
# Epoch 103/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5026 - mean_squared_error: 5.0156 - mee_keras: 2.4476 - r2_keras: 0.9969 - val_loss: 10.9204 - val_mean_squared_error: 8.4380 - val_mee_keras: 3.1026 - val_r2_keras: 0.9947
# Epoch 104/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.6697 - mean_squared_error: 5.1923 - mee_keras: 2.4832 - r2_keras: 0.9968 - val_loss: 10.6187 - val_mean_squared_error: 8.1384 - val_mee_keras: 3.1355 - val_r2_keras: 0.9951
# Epoch 105/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5762 - mean_squared_error: 5.0973 - mee_keras: 2.4532 - r2_keras: 0.9969 - val_loss: 10.5826 - val_mean_squared_error: 8.0991 - val_mee_keras: 3.1891 - val_r2_keras: 0.9950
# Epoch 106/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.6163 - mean_squared_error: 5.1382 - mee_keras: 2.4909 - r2_keras: 0.9969 - val_loss: 10.0697 - val_mean_squared_error: 7.5923 - val_mee_keras: 2.9890 - val_r2_keras: 0.9954
# Epoch 107/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.4615 - mean_squared_error: 4.9886 - mee_keras: 2.4294 - r2_keras: 0.9969 - val_loss: 10.7195 - val_mean_squared_error: 8.2530 - val_mee_keras: 3.1265 - val_r2_keras: 0.9950
# Epoch 108/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.4509 - mean_squared_error: 4.9830 - mee_keras: 2.4284 - r2_keras: 0.9970 - val_loss: 10.1184 - val_mean_squared_error: 7.6524 - val_mee_keras: 3.0106 - val_r2_keras: 0.9953
# Epoch 109/500
# 17/17 [==============================] - 0s 6ms/step - loss: 7.3429 - mean_squared_error: 4.8806 - mee_keras: 2.4126 - r2_keras: 0.9970 - val_loss: 9.9538 - val_mean_squared_error: 7.4931 - val_mee_keras: 2.9756 - val_r2_keras: 0.9954
# Epoch 110/500
# 17/17 [==============================] - 0s 8ms/step - loss: 7.5534 - mean_squared_error: 5.0901 - mee_keras: 2.4873 - r2_keras: 0.9969 - val_loss: 10.1808 - val_mean_squared_error: 7.7213 - val_mee_keras: 3.0901 - val_r2_keras: 0.9953
# Epoch 111/500
# 17/17 [==============================] - 0s 8ms/step - loss: 7.2301 - mean_squared_error: 4.7699 - mee_keras: 2.3949 - r2_keras: 0.9971 - val_loss: 10.2549 - val_mean_squared_error: 7.8046 - val_mee_keras: 3.1706 - val_r2_keras: 0.9952
# Epoch 112/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.3150 - mean_squared_error: 4.8608 - mee_keras: 2.4044 - r2_keras: 0.9971 - val_loss: 10.2823 - val_mean_squared_error: 7.8300 - val_mee_keras: 3.0405 - val_r2_keras: 0.9951
# Epoch 113/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.6465 - mean_squared_error: 5.1952 - mee_keras: 2.4649 - r2_keras: 0.9968 - val_loss: 12.5975 - val_mean_squared_error: 10.1564 - val_mee_keras: 3.5967 - val_r2_keras: 0.9939
# Epoch 114/500
# 17/17 [==============================] - 0s 8ms/step - loss: 7.5416 - mean_squared_error: 5.0996 - mee_keras: 2.4584 - r2_keras: 0.9969 - val_loss: 10.6080 - val_mean_squared_error: 8.1723 - val_mee_keras: 3.1955 - val_r2_keras: 0.9950
# Epoch 115/500
# 17/17 [==============================] - 0s 6ms/step - loss: 7.2931 - mean_squared_error: 4.8520 - mee_keras: 2.4214 - r2_keras: 0.9970 - val_loss: 10.1205 - val_mean_squared_error: 7.6845 - val_mee_keras: 3.0648 - val_r2_keras: 0.9953
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/500
# 17/17 [==============================] - 0s 9ms/step - loss: 9.0274 - mean_squared_error: 6.1077 - mee_keras: 2.6104 - r2_keras: 0.9963 - val_loss: 10.9810 - val_mean_squared_error: 8.0612 - val_mee_keras: 2.9702 - val_r2_keras: 0.9952
# Epoch 2/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.6922 - mean_squared_error: 5.7790 - mee_keras: 2.6348 - r2_keras: 0.9965 - val_loss: 11.0588 - val_mean_squared_error: 8.1466 - val_mee_keras: 3.0536 - val_r2_keras: 0.9952
# Epoch 3/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.5932 - mean_squared_error: 5.6876 - mee_keras: 2.5751 - r2_keras: 0.9965 - val_loss: 12.0201 - val_mean_squared_error: 9.1281 - val_mee_keras: 3.1939 - val_r2_keras: 0.9947
# Epoch 4/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.5388 - mean_squared_error: 5.6433 - mee_keras: 2.5779 - r2_keras: 0.9966 - val_loss: 10.8656 - val_mean_squared_error: 7.9704 - val_mee_keras: 2.9993 - val_r2_keras: 0.9953
# Epoch 5/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.4510 - mean_squared_error: 5.5639 - mee_keras: 2.5515 - r2_keras: 0.9966 - val_loss: 10.6406 - val_mean_squared_error: 7.7602 - val_mee_keras: 2.9975 - val_r2_keras: 0.9955
# Epoch 6/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.6280 - mean_squared_error: 5.7520 - mee_keras: 2.6086 - r2_keras: 0.9965 - val_loss: 11.0210 - val_mean_squared_error: 8.1420 - val_mee_keras: 3.0689 - val_r2_keras: 0.9952
# Epoch 7/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4655 - mean_squared_error: 5.5977 - mee_keras: 2.5548 - r2_keras: 0.9966 - val_loss: 11.8268 - val_mean_squared_error: 8.9702 - val_mee_keras: 3.1561 - val_r2_keras: 0.9948
# Epoch 8/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4521 - mean_squared_error: 5.5935 - mee_keras: 2.6037 - r2_keras: 0.9966 - val_loss: 10.7702 - val_mean_squared_error: 7.9123 - val_mee_keras: 3.0210 - val_r2_keras: 0.9953
# Epoch 9/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.5049 - mean_squared_error: 5.6575 - mee_keras: 2.6040 - r2_keras: 0.9966 - val_loss: 10.9069 - val_mean_squared_error: 8.0712 - val_mee_keras: 2.9900 - val_r2_keras: 0.9953
# Epoch 10/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.6423 - mean_squared_error: 5.8101 - mee_keras: 2.6157 - r2_keras: 0.9964 - val_loss: 10.2383 - val_mean_squared_error: 7.4115 - val_mee_keras: 2.9012 - val_r2_keras: 0.9957
# Epoch 11/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.8088 - mean_squared_error: 5.9827 - mee_keras: 2.6380 - r2_keras: 0.9963 - val_loss: 11.4705 - val_mean_squared_error: 8.6484 - val_mee_keras: 3.1355 - val_r2_keras: 0.9950
# Epoch 12/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.6524 - mean_squared_error: 5.8341 - mee_keras: 2.5993 - r2_keras: 0.9965 - val_loss: 11.9159 - val_mean_squared_error: 9.1062 - val_mee_keras: 3.1726 - val_r2_keras: 0.9947
# Epoch 13/500
# 17/17 [==============================] - 0s 9ms/step - loss: 8.6470 - mean_squared_error: 5.8319 - mee_keras: 2.5857 - r2_keras: 0.9965 - val_loss: 11.8162 - val_mean_squared_error: 8.9994 - val_mee_keras: 3.1149 - val_r2_keras: 0.9946
# Epoch 14/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4519 - mean_squared_error: 5.6454 - mee_keras: 2.5479 - r2_keras: 0.9965 - val_loss: 10.4065 - val_mean_squared_error: 7.6047 - val_mee_keras: 2.9578 - val_r2_keras: 0.9955
# Epoch 15/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.4466 - mean_squared_error: 5.6467 - mee_keras: 2.5660 - r2_keras: 0.9966 - val_loss: 10.4416 - val_mean_squared_error: 7.6391 - val_mee_keras: 2.9679 - val_r2_keras: 0.9955
# Epoch 16/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.3704 - mean_squared_error: 5.5689 - mee_keras: 2.5408 - r2_keras: 0.9966 - val_loss: 11.6239 - val_mean_squared_error: 8.8313 - val_mee_keras: 3.1678 - val_r2_keras: 0.9948
# Epoch 17/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4758 - mean_squared_error: 5.6810 - mee_keras: 2.5341 - r2_keras: 0.9965 - val_loss: 10.6055 - val_mean_squared_error: 7.8139 - val_mee_keras: 3.0472 - val_r2_keras: 0.9955
# Epoch 18/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4195 - mean_squared_error: 5.6326 - mee_keras: 2.5482 - r2_keras: 0.9965 - val_loss: 11.5788 - val_mean_squared_error: 8.7874 - val_mee_keras: 3.0953 - val_r2_keras: 0.9948
# Epoch 19/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.4044 - mean_squared_error: 5.6242 - mee_keras: 2.5489 - r2_keras: 0.9966 - val_loss: 10.6383 - val_mean_squared_error: 7.8600 - val_mee_keras: 2.9405 - val_r2_keras: 0.9954
# Epoch 20/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.6532 - mean_squared_error: 5.8842 - mee_keras: 2.6082 - r2_keras: 0.9964 - val_loss: 11.7804 - val_mean_squared_error: 9.0085 - val_mee_keras: 3.1226 - val_r2_keras: 0.9946
# Epoch 21/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.5519 - mean_squared_error: 5.7879 - mee_keras: 2.5705 - r2_keras: 0.9965 - val_loss: 10.8100 - val_mean_squared_error: 8.0470 - val_mee_keras: 3.0525 - val_r2_keras: 0.9953
# Epoch 22/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4590 - mean_squared_error: 5.6983 - mee_keras: 2.6167 - r2_keras: 0.9965 - val_loss: 10.6435 - val_mean_squared_error: 7.8837 - val_mee_keras: 2.9231 - val_r2_keras: 0.9953
# Epoch 23/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.3351 - mean_squared_error: 5.5818 - mee_keras: 2.5423 - r2_keras: 0.9966 - val_loss: 11.1326 - val_mean_squared_error: 8.3877 - val_mee_keras: 3.0588 - val_r2_keras: 0.9951
# Epoch 24/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4564 - mean_squared_error: 5.7086 - mee_keras: 2.5470 - r2_keras: 0.9965 - val_loss: 11.8106 - val_mean_squared_error: 9.0678 - val_mee_keras: 3.1915 - val_r2_keras: 0.9947
# Epoch 25/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.7674 - mean_squared_error: 6.0230 - mee_keras: 2.6389 - r2_keras: 0.9963 - val_loss: 10.8937 - val_mean_squared_error: 8.1541 - val_mee_keras: 3.1740 - val_r2_keras: 0.9952
# Epoch 26/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2564 - mean_squared_error: 5.5234 - mee_keras: 2.5925 - r2_keras: 0.9966 - val_loss: 10.1115 - val_mean_squared_error: 7.3821 - val_mee_keras: 2.8926 - val_r2_keras: 0.9957
# Epoch 27/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.3449 - mean_squared_error: 5.6201 - mee_keras: 2.5938 - r2_keras: 0.9965 - val_loss: 10.1710 - val_mean_squared_error: 7.4470 - val_mee_keras: 2.9048 - val_r2_keras: 0.9957
# Epoch 28/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.3039 - mean_squared_error: 5.5859 - mee_keras: 2.5889 - r2_keras: 0.9966 - val_loss: 11.7381 - val_mean_squared_error: 9.0132 - val_mee_keras: 3.1231 - val_r2_keras: 0.9946
# Epoch 29/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.3293 - mean_squared_error: 5.6139 - mee_keras: 2.5801 - r2_keras: 0.9966 - val_loss: 10.7058 - val_mean_squared_error: 7.9875 - val_mee_keras: 3.0276 - val_r2_keras: 0.9953
# Epoch 30/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.3180 - mean_squared_error: 5.6030 - mee_keras: 2.5826 - r2_keras: 0.9965 - val_loss: 11.8166 - val_mean_squared_error: 9.1079 - val_mee_keras: 3.2777 - val_r2_keras: 0.9947
# Epoch 31/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.3121 - mean_squared_error: 5.5979 - mee_keras: 2.5873 - r2_keras: 0.9966 - val_loss: 10.1573 - val_mean_squared_error: 7.4394 - val_mee_keras: 2.8818 - val_r2_keras: 0.9957
# Epoch 32/500
# 17/17 [==============================] - 0s 10ms/step - loss: 8.4731 - mean_squared_error: 5.7623 - mee_keras: 2.5805 - r2_keras: 0.9965 - val_loss: 10.4432 - val_mean_squared_error: 7.7320 - val_mee_keras: 2.9127 - val_r2_keras: 0.9954
# Epoch 33/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.3505 - mean_squared_error: 5.6435 - mee_keras: 2.5504 - r2_keras: 0.9965 - val_loss: 11.7736 - val_mean_squared_error: 9.0682 - val_mee_keras: 3.1896 - val_r2_keras: 0.9947
# Epoch 34/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.5515 - mean_squared_error: 5.8486 - mee_keras: 2.5899 - r2_keras: 0.9964 - val_loss: 10.9211 - val_mean_squared_error: 8.2288 - val_mee_keras: 3.1043 - val_r2_keras: 0.9952
# Epoch 35/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2159 - mean_squared_error: 5.5246 - mee_keras: 2.5256 - r2_keras: 0.9967 - val_loss: 10.8706 - val_mean_squared_error: 8.1857 - val_mee_keras: 3.2254 - val_r2_keras: 0.9952
# Epoch 36/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1051 - mean_squared_error: 5.4235 - mee_keras: 2.5748 - r2_keras: 0.9967 - val_loss: 11.0668 - val_mean_squared_error: 8.3904 - val_mee_keras: 3.0994 - val_r2_keras: 0.9951
# Epoch 37/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.1248 - mean_squared_error: 5.4475 - mee_keras: 2.5240 - r2_keras: 0.9967 - val_loss: 10.4853 - val_mean_squared_error: 7.8173 - val_mee_keras: 2.9998 - val_r2_keras: 0.9954
# Epoch 38/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.7626 - mean_squared_error: 6.0950 - mee_keras: 2.6076 - r2_keras: 0.9963 - val_loss: 10.5011 - val_mean_squared_error: 7.8363 - val_mee_keras: 3.0215 - val_r2_keras: 0.9954
# Epoch 39/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.3437 - mean_squared_error: 5.6778 - mee_keras: 2.5863 - r2_keras: 0.9966 - val_loss: 10.4577 - val_mean_squared_error: 7.7886 - val_mee_keras: 2.9479 - val_r2_keras: 0.9954
# Epoch 40/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.0176 - mean_squared_error: 5.3555 - mee_keras: 2.5331 - r2_keras: 0.9967 - val_loss: 10.9507 - val_mean_squared_error: 8.2898 - val_mee_keras: 3.1816 - val_r2_keras: 0.9951
# Epoch 41/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1728 - mean_squared_error: 5.5167 - mee_keras: 2.5487 - r2_keras: 0.9966 - val_loss: 10.1788 - val_mean_squared_error: 7.5232 - val_mee_keras: 2.8826 - val_r2_keras: 0.9956
# Epoch 42/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.0456 - mean_squared_error: 5.3938 - mee_keras: 2.4971 - r2_keras: 0.9967 - val_loss: 10.3188 - val_mean_squared_error: 7.6693 - val_mee_keras: 2.9961 - val_r2_keras: 0.9955
# Epoch 43/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.3153 - mean_squared_error: 5.6651 - mee_keras: 2.5908 - r2_keras: 0.9965 - val_loss: 10.3558 - val_mean_squared_error: 7.6990 - val_mee_keras: 2.9050 - val_r2_keras: 0.9955
# Epoch 44/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1077 - mean_squared_error: 5.4592 - mee_keras: 2.5251 - r2_keras: 0.9967 - val_loss: 10.5391 - val_mean_squared_error: 7.8893 - val_mee_keras: 3.0562 - val_r2_keras: 0.9954
# Epoch 45/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2252 - mean_squared_error: 5.5822 - mee_keras: 2.5559 - r2_keras: 0.9966 - val_loss: 10.2606 - val_mean_squared_error: 7.6136 - val_mee_keras: 2.9747 - val_r2_keras: 0.9955
# Epoch 46/500
# 17/17 [==============================] - 0s 8ms/step - loss: 7.9386 - mean_squared_error: 5.2981 - mee_keras: 2.5092 - r2_keras: 0.9968 - val_loss: 11.0235 - val_mean_squared_error: 8.3853 - val_mee_keras: 3.1234 - val_r2_keras: 0.9951
# Epoch 47/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9470 - mean_squared_error: 5.3073 - mee_keras: 2.5064 - r2_keras: 0.9967 - val_loss: 10.5138 - val_mean_squared_error: 7.8798 - val_mee_keras: 3.0493 - val_r2_keras: 0.9954
# Epoch 48/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8203 - mean_squared_error: 5.1908 - mee_keras: 2.4894 - r2_keras: 0.9968 - val_loss: 10.3608 - val_mean_squared_error: 7.7397 - val_mee_keras: 3.0052 - val_r2_keras: 0.9955
# Epoch 49/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2225 - mean_squared_error: 5.6019 - mee_keras: 2.5747 - r2_keras: 0.9966 - val_loss: 10.1370 - val_mean_squared_error: 7.5136 - val_mee_keras: 2.8932 - val_r2_keras: 0.9956
# Epoch 50/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.2005 - mean_squared_error: 5.5814 - mee_keras: 2.5727 - r2_keras: 0.9966 - val_loss: 11.2711 - val_mean_squared_error: 8.6633 - val_mee_keras: 3.1148 - val_r2_keras: 0.9949
# Epoch 51/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1475 - mean_squared_error: 5.5338 - mee_keras: 2.5630 - r2_keras: 0.9966 - val_loss: 10.2747 - val_mean_squared_error: 7.6548 - val_mee_keras: 2.9392 - val_r2_keras: 0.9955
# Epoch 52/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1036 - mean_squared_error: 5.4895 - mee_keras: 2.5220 - r2_keras: 0.9967 - val_loss: 12.1496 - val_mean_squared_error: 9.5415 - val_mee_keras: 3.3957 - val_r2_keras: 0.9944
# Epoch 53/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.1546 - mean_squared_error: 5.5412 - mee_keras: 2.5359 - r2_keras: 0.9966 - val_loss: 10.5137 - val_mean_squared_error: 7.9063 - val_mee_keras: 2.9952 - val_r2_keras: 0.9954
# Epoch 54/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2482 - mean_squared_error: 5.6375 - mee_keras: 2.5694 - r2_keras: 0.9966 - val_loss: 10.5968 - val_mean_squared_error: 7.9910 - val_mee_keras: 3.0336 - val_r2_keras: 0.9953
# Epoch 55/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1100 - mean_squared_error: 5.5015 - mee_keras: 2.5497 - r2_keras: 0.9966 - val_loss: 13.3450 - val_mean_squared_error: 10.7462 - val_mee_keras: 3.5130 - val_r2_keras: 0.9937
# Epoch 56/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2614 - mean_squared_error: 5.6586 - mee_keras: 2.5413 - r2_keras: 0.9966 - val_loss: 11.3575 - val_mean_squared_error: 8.7564 - val_mee_keras: 3.2641 - val_r2_keras: 0.9948
# Epoch 57/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.1273 - mean_squared_error: 5.5251 - mee_keras: 2.5464 - r2_keras: 0.9966 - val_loss: 12.3248 - val_mean_squared_error: 9.7192 - val_mee_keras: 3.2592 - val_r2_keras: 0.9942
# Epoch 58/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.3152 - mean_squared_error: 5.7182 - mee_keras: 2.6281 - r2_keras: 0.9965 - val_loss: 10.5188 - val_mean_squared_error: 7.9287 - val_mee_keras: 3.0183 - val_r2_keras: 0.9954
# Epoch 59/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9701 - mean_squared_error: 5.3784 - mee_keras: 2.5070 - r2_keras: 0.9967 - val_loss: 10.2057 - val_mean_squared_error: 7.6139 - val_mee_keras: 2.8949 - val_r2_keras: 0.9956
# Epoch 60/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8110 - mean_squared_error: 5.2215 - mee_keras: 2.4872 - r2_keras: 0.9968 - val_loss: 10.6521 - val_mean_squared_error: 8.0564 - val_mee_keras: 3.0659 - val_r2_keras: 0.9952
# Epoch 61/500
# 17/17 [==============================] - 0s 8ms/step - loss: 8.0519 - mean_squared_error: 5.4644 - mee_keras: 2.5416 - r2_keras: 0.9966 - val_loss: 10.8498 - val_mean_squared_error: 8.2731 - val_mee_keras: 3.1709 - val_r2_keras: 0.9951
# Epoch 62/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4947 - mean_squared_error: 5.9155 - mee_keras: 2.6184 - r2_keras: 0.9963 - val_loss: 10.8318 - val_mean_squared_error: 8.2489 - val_mee_keras: 3.1791 - val_r2_keras: 0.9952
# Epoch 63/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.0246 - mean_squared_error: 5.4440 - mee_keras: 2.5258 - r2_keras: 0.9966 - val_loss: 10.5493 - val_mean_squared_error: 7.9700 - val_mee_keras: 3.0253 - val_r2_keras: 0.9953
# Epoch 64/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1332 - mean_squared_error: 5.5576 - mee_keras: 2.5411 - r2_keras: 0.9966 - val_loss: 10.3821 - val_mean_squared_error: 7.8105 - val_mee_keras: 2.9948 - val_r2_keras: 0.9954
# Epoch 65/500
# 17/17 [==============================] - 0s 8ms/step - loss: 7.9502 - mean_squared_error: 5.3769 - mee_keras: 2.4887 - r2_keras: 0.9967 - val_loss: 10.8242 - val_mean_squared_error: 8.2459 - val_mee_keras: 3.1428 - val_r2_keras: 0.9951
# Epoch 66/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9297 - mean_squared_error: 5.3505 - mee_keras: 2.5224 - r2_keras: 0.9967 - val_loss: 13.6737 - val_mean_squared_error: 11.1016 - val_mee_keras: 3.5219 - val_r2_keras: 0.9935
# Epoch 67/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1586 - mean_squared_error: 5.5807 - mee_keras: 2.5607 - r2_keras: 0.9966 - val_loss: 10.9009 - val_mean_squared_error: 8.3202 - val_mee_keras: 3.1250 - val_r2_keras: 0.9951
# Epoch 68/500
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9204 - mean_squared_error: 5.3472 - mee_keras: 2.5216 - r2_keras: 0.9967 - val_loss: 10.5524 - val_mean_squared_error: 7.9853 - val_mee_keras: 3.0866 - val_r2_keras: 0.9953
# Epoch 69/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1645 - mean_squared_error: 5.5939 - mee_keras: 2.5256 - r2_keras: 0.9966 - val_loss: 10.5821 - val_mean_squared_error: 8.0095 - val_mee_keras: 2.9731 - val_r2_keras: 0.9953
# Epoch 70/500
# 17/17 [==============================] - 0s 7ms/step - loss: 8.0092 - mean_squared_error: 5.4436 - mee_keras: 2.5287 - r2_keras: 0.9967 - val_loss: 11.7433 - val_mean_squared_error: 9.1851 - val_mee_keras: 3.2810 - val_r2_keras: 0.9946
# Epoch 71/500
# ...
# Epoch 44/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.5235 - mean_squared_error: 3.1958 - mee_keras: 2.0777 - r2_keras: 0.9980 - val_loss: 11.7736 - val_mean_squared_error: 9.4473 - val_mee_keras: 3.2937 - val_r2_keras: 0.9943
# Epoch 45/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.5568 - mean_squared_error: 3.2320 - mee_keras: 2.0707 - r2_keras: 0.9980 - val_loss: 11.9593 - val_mean_squared_error: 9.6257 - val_mee_keras: 3.3462 - val_r2_keras: 0.9942
# Epoch 46/500
# 17/17 [==============================] - 0s 10ms/step - loss: 5.4608 - mean_squared_error: 3.1322 - mee_keras: 2.0165 - r2_keras: 0.9981 - val_loss: 12.0512 - val_mean_squared_error: 9.7274 - val_mee_keras: 3.3414 - val_r2_keras: 0.9941
# Epoch 47/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.5064 - mean_squared_error: 3.1812 - mee_keras: 2.0204 - r2_keras: 0.9981 - val_loss: 12.7235 - val_mean_squared_error: 10.3928 - val_mee_keras: 3.5183 - val_r2_keras: 0.9937
# Epoch 48/500
# 17/17 [==============================] - 0s 13ms/step - loss: 5.4811 - mean_squared_error: 3.1506 - mee_keras: 2.0625 - r2_keras: 0.9981 - val_loss: 11.9756 - val_mean_squared_error: 9.6497 - val_mee_keras: 3.4246 - val_r2_keras: 0.9942
# Epoch 49/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.3754 - mean_squared_error: 3.0446 - mee_keras: 1.9705 - r2_keras: 0.9981 - val_loss: 11.8262 - val_mean_squared_error: 9.5052 - val_mee_keras: 3.4066 - val_r2_keras: 0.9943
# Epoch 50/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.6773 - mean_squared_error: 3.3505 - mee_keras: 2.0764 - r2_keras: 0.9979 - val_loss: 11.6672 - val_mean_squared_error: 9.3364 - val_mee_keras: 3.2889 - val_r2_keras: 0.9943
# Epoch 51/500
# 17/17 [==============================] - 0s 11ms/step - loss: 5.6304 - mean_squared_error: 3.3003 - mee_keras: 2.0472 - r2_keras: 0.9980 - val_loss: 11.9862 - val_mean_squared_error: 9.6524 - val_mee_keras: 3.3371 - val_r2_keras: 0.9942
# Epoch 52/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.5199 - mean_squared_error: 3.1920 - mee_keras: 2.0248 - r2_keras: 0.9980 - val_loss: 12.5681 - val_mean_squared_error: 10.2469 - val_mee_keras: 3.4147 - val_r2_keras: 0.9938
# Epoch 53/500
# 17/17 [==============================] - 0s 10ms/step - loss: 5.5346 - mean_squared_error: 3.2058 - mee_keras: 2.0098 - r2_keras: 0.9980 - val_loss: 11.9776 - val_mean_squared_error: 9.6499 - val_mee_keras: 3.3888 - val_r2_keras: 0.9942
# Epoch 54/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.4880 - mean_squared_error: 3.1556 - mee_keras: 1.9884 - r2_keras: 0.9981 - val_loss: 11.6053 - val_mean_squared_error: 9.2707 - val_mee_keras: 3.2942 - val_r2_keras: 0.9944
# Epoch 55/500
# 17/17 [==============================] - 0s 11ms/step - loss: 5.4455 - mean_squared_error: 3.1143 - mee_keras: 2.0268 - r2_keras: 0.9981 - val_loss: 12.0163 - val_mean_squared_error: 9.6900 - val_mee_keras: 3.3245 - val_r2_keras: 0.9941
# Epoch 56/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.5848 - mean_squared_error: 3.2551 - mee_keras: 2.0397 - r2_keras: 0.9980 - val_loss: 12.1285 - val_mean_squared_error: 9.8012 - val_mee_keras: 3.3801 - val_r2_keras: 0.9940
# Epoch 57/500
# 17/17 [==============================] - 0s 11ms/step - loss: 5.4700 - mean_squared_error: 3.1381 - mee_keras: 2.0050 - r2_keras: 0.9981 - val_loss: 12.1954 - val_mean_squared_error: 9.8634 - val_mee_keras: 3.3738 - val_r2_keras: 0.9940
# Epoch 58/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.4584 - mean_squared_error: 3.1244 - mee_keras: 1.9892 - r2_keras: 0.9981 - val_loss: 12.3617 - val_mean_squared_error: 10.0377 - val_mee_keras: 3.4727 - val_r2_keras: 0.9939
# Epoch 59/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.6768 - mean_squared_error: 3.3416 - mee_keras: 2.0438 - r2_keras: 0.9980 - val_loss: 12.2625 - val_mean_squared_error: 9.9211 - val_mee_keras: 3.3388 - val_r2_keras: 0.9940
# Epoch 60/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.5147 - mean_squared_error: 3.1780 - mee_keras: 2.0222 - r2_keras: 0.9981 - val_loss: 12.3939 - val_mean_squared_error: 10.0601 - val_mee_keras: 3.5652 - val_r2_keras: 0.9939
# Epoch 61/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.4340 - mean_squared_error: 3.0956 - mee_keras: 2.0035 - r2_keras: 0.9981 - val_loss: 12.4410 - val_mean_squared_error: 10.0965 - val_mee_keras: 3.4246 - val_r2_keras: 0.9939
# Epoch 62/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.4172 - mean_squared_error: 3.0786 - mee_keras: 2.0306 - r2_keras: 0.9981 - val_loss: 12.0737 - val_mean_squared_error: 9.7360 - val_mee_keras: 3.5288 - val_r2_keras: 0.9941
# Epoch 63/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.5730 - mean_squared_error: 3.2400 - mee_keras: 2.0213 - r2_keras: 0.9980 - val_loss: 11.6461 - val_mean_squared_error: 9.3099 - val_mee_keras: 3.2997 - val_r2_keras: 0.9944
# Epoch 64/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.3718 - mean_squared_error: 3.0387 - mee_keras: 1.9735 - r2_keras: 0.9981 - val_loss: 12.6260 - val_mean_squared_error: 10.2955 - val_mee_keras: 3.5911 - val_r2_keras: 0.9937
# Epoch 65/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.3511 - mean_squared_error: 3.0190 - mee_keras: 1.9697 - r2_keras: 0.9982 - val_loss: 12.0522 - val_mean_squared_error: 9.7244 - val_mee_keras: 3.4525 - val_r2_keras: 0.9941
# Epoch 66/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.4704 - mean_squared_error: 3.1363 - mee_keras: 1.9647 - r2_keras: 0.9981 - val_loss: 11.6798 - val_mean_squared_error: 9.3463 - val_mee_keras: 3.3325 - val_r2_keras: 0.9943
# Epoch 67/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.3427 - mean_squared_error: 3.0072 - mee_keras: 1.9683 - r2_keras: 0.9982 - val_loss: 12.3028 - val_mean_squared_error: 9.9648 - val_mee_keras: 3.3951 - val_r2_keras: 0.9940
# Epoch 68/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.4795 - mean_squared_error: 3.1413 - mee_keras: 1.9694 - r2_keras: 0.9981 - val_loss: 11.9505 - val_mean_squared_error: 9.6051 - val_mee_keras: 3.3207 - val_r2_keras: 0.9942
# Epoch 69/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.5487 - mean_squared_error: 3.2069 - mee_keras: 2.0366 - r2_keras: 0.9980 - val_loss: 11.7528 - val_mean_squared_error: 9.4082 - val_mee_keras: 3.3076 - val_r2_keras: 0.9943
# Epoch 70/500
# 17/17 [==============================] - 0s 11ms/step - loss: 5.4671 - mean_squared_error: 3.1255 - mee_keras: 1.9849 - r2_keras: 0.9981 - val_loss: 12.7287 - val_mean_squared_error: 10.3894 - val_mee_keras: 3.4619 - val_r2_keras: 0.9936
# Epoch 71/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.3800 - mean_squared_error: 3.0413 - mee_keras: 1.9940 - r2_keras: 0.9982 - val_loss: 11.5330 - val_mean_squared_error: 9.1993 - val_mee_keras: 3.2780 - val_r2_keras: 0.9944
# Epoch 72/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.5424 - mean_squared_error: 3.2068 - mee_keras: 1.9803 - r2_keras: 0.9980 - val_loss: 11.5284 - val_mean_squared_error: 9.1993 - val_mee_keras: 3.3463 - val_r2_keras: 0.9944
# Epoch 73/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.2649 - mean_squared_error: 2.9288 - mee_keras: 1.9781 - r2_keras: 0.9982 - val_loss: 12.7243 - val_mean_squared_error: 10.3919 - val_mee_keras: 3.5372 - val_r2_keras: 0.9937
# Epoch 74/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.3256 - mean_squared_error: 2.9903 - mee_keras: 1.9832 - r2_keras: 0.9982 - val_loss: 12.3519 - val_mean_squared_error: 10.0141 - val_mee_keras: 3.5619 - val_r2_keras: 0.9939
# Epoch 75/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.3024 - mean_squared_error: 2.9690 - mee_keras: 1.9720 - r2_keras: 0.9982 - val_loss: 11.9098 - val_mean_squared_error: 9.5763 - val_mee_keras: 3.3411 - val_r2_keras: 0.9942
# Epoch 76/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.2851 - mean_squared_error: 2.9574 - mee_keras: 1.9789 - r2_keras: 0.9982 - val_loss: 12.1675 - val_mean_squared_error: 9.8388 - val_mee_keras: 3.3203 - val_r2_keras: 0.9941
# Epoch 77/500
# 17/17 [==============================] - 0s 11ms/step - loss: 5.3580 - mean_squared_error: 3.0293 - mee_keras: 1.9641 - r2_keras: 0.9982 - val_loss: 11.9877 - val_mean_squared_error: 9.6544 - val_mee_keras: 3.4158 - val_r2_keras: 0.9942
# Epoch 78/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.6183 - mean_squared_error: 3.2912 - mee_keras: 2.0787 - r2_keras: 0.9980 - val_loss: 11.8750 - val_mean_squared_error: 9.5548 - val_mee_keras: 3.3531 - val_r2_keras: 0.9942
# Epoch 79/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.4019 - mean_squared_error: 3.0759 - mee_keras: 1.9870 - r2_keras: 0.9981 - val_loss: 12.1126 - val_mean_squared_error: 9.7822 - val_mee_keras: 3.5208 - val_r2_keras: 0.9941
# Epoch 80/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.3512 - mean_squared_error: 3.0270 - mee_keras: 2.0212 - r2_keras: 0.9982 - val_loss: 12.2746 - val_mean_squared_error: 9.9447 - val_mee_keras: 3.3736 - val_r2_keras: 0.9940
# Epoch 81/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.3795 - mean_squared_error: 3.0532 - mee_keras: 1.9843 - r2_keras: 0.9981 - val_loss: 11.5371 - val_mean_squared_error: 9.2157 - val_mee_keras: 3.3264 - val_r2_keras: 0.9944
# Epoch 82/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.4319 - mean_squared_error: 3.1092 - mee_keras: 2.0114 - r2_keras: 0.9981 - val_loss: 12.0732 - val_mean_squared_error: 9.7506 - val_mee_keras: 3.4780 - val_r2_keras: 0.9941
# Epoch 83/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.4160 - mean_squared_error: 3.0916 - mee_keras: 1.9857 - r2_keras: 0.9981 - val_loss: 11.7803 - val_mean_squared_error: 9.4564 - val_mee_keras: 3.3972 - val_r2_keras: 0.9943
# Epoch 84/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.4221 - mean_squared_error: 3.0988 - mee_keras: 1.9827 - r2_keras: 0.9981 - val_loss: 12.2050 - val_mean_squared_error: 9.8814 - val_mee_keras: 3.4684 - val_r2_keras: 0.9940
# Epoch 85/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.4303 - mean_squared_error: 3.1050 - mee_keras: 2.0654 - r2_keras: 0.9981 - val_loss: 12.6545 - val_mean_squared_error: 10.3346 - val_mee_keras: 3.4824 - val_r2_keras: 0.9937
# Epoch 86/500
# 17/17 [==============================] - 0s 10ms/step - loss: 5.2553 - mean_squared_error: 2.9344 - mee_keras: 1.9707 - r2_keras: 0.9982 - val_loss: 12.0494 - val_mean_squared_error: 9.7241 - val_mee_keras: 3.4689 - val_r2_keras: 0.9941
# Epoch 87/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.3557 - mean_squared_error: 3.0343 - mee_keras: 2.0176 - r2_keras: 0.9982 - val_loss: 11.9296 - val_mean_squared_error: 9.6117 - val_mee_keras: 3.3938 - val_r2_keras: 0.9942
# Epoch 88/500
# 17/17 [==============================] - 0s 10ms/step - loss: 5.4157 - mean_squared_error: 3.0942 - mee_keras: 2.0205 - r2_keras: 0.9981 - val_loss: 11.9947 - val_mean_squared_error: 9.6737 - val_mee_keras: 3.3412 - val_r2_keras: 0.9942
# Epoch 89/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.2016 - mean_squared_error: 2.8838 - mee_keras: 1.9910 - r2_keras: 0.9982 - val_loss: 11.9639 - val_mean_squared_error: 9.6489 - val_mee_keras: 3.4321 - val_r2_keras: 0.9942
# Epoch 90/500
# 17/17 [==============================] - 0s 10ms/step - loss: 5.3988 - mean_squared_error: 3.0779 - mee_keras: 2.0071 - r2_keras: 0.9981 - val_loss: 12.9581 - val_mean_squared_error: 10.6388 - val_mee_keras: 3.6259 - val_r2_keras: 0.9935
# Epoch 91/500
# 17/17 [==============================] - 0s 10ms/step - loss: 5.4541 - mean_squared_error: 3.1347 - mee_keras: 2.0140 - r2_keras: 0.9981 - val_loss: 12.9167 - val_mean_squared_error: 10.6051 - val_mee_keras: 3.5225 - val_r2_keras: 0.9935
# Epoch 92/500
# 17/17 [==============================] - 0s 11ms/step - loss: 5.3430 - mean_squared_error: 3.0290 - mee_keras: 1.9742 - r2_keras: 0.9982 - val_loss: 11.5621 - val_mean_squared_error: 9.2479 - val_mee_keras: 3.2894 - val_r2_keras: 0.9944
# Epoch 93/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.3521 - mean_squared_error: 3.0386 - mee_keras: 1.9564 - r2_keras: 0.9982 - val_loss: 12.7323 - val_mean_squared_error: 10.4116 - val_mee_keras: 3.5906 - val_r2_keras: 0.9937
# Epoch 94/500
# 17/17 [==============================] - 0s 13ms/step - loss: 5.3747 - mean_squared_error: 3.0592 - mee_keras: 2.0178 - r2_keras: 0.9981 - val_loss: 12.0872 - val_mean_squared_error: 9.7695 - val_mee_keras: 3.4097 - val_r2_keras: 0.9941
# Epoch 95/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.4338 - mean_squared_error: 3.1189 - mee_keras: 1.9987 - r2_keras: 0.9981 - val_loss: 13.7127 - val_mean_squared_error: 11.4038 - val_mee_keras: 3.7954 - val_r2_keras: 0.9930
# Epoch 96/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.2721 - mean_squared_error: 2.9553 - mee_keras: 1.9807 - r2_keras: 0.9982 - val_loss: 11.9331 - val_mean_squared_error: 9.6128 - val_mee_keras: 3.4128 - val_r2_keras: 0.9942
# Epoch 97/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.3069 - mean_squared_error: 2.9879 - mee_keras: 1.9809 - r2_keras: 0.9982 - val_loss: 12.1495 - val_mean_squared_error: 9.8366 - val_mee_keras: 3.4103 - val_r2_keras: 0.9940
# Epoch 98/500
# 17/17 [==============================] - 0s 11ms/step - loss: 5.3293 - mean_squared_error: 3.0112 - mee_keras: 1.9793 - r2_keras: 0.9982 - val_loss: 12.0405 - val_mean_squared_error: 9.7213 - val_mee_keras: 3.5159 - val_r2_keras: 0.9941
# Epoch 99/500
# 17/17 [==============================] - 0s 10ms/step - loss: 5.4007 - mean_squared_error: 3.0839 - mee_keras: 2.0344 - r2_keras: 0.9981 - val_loss: 12.3073 - val_mean_squared_error: 9.9841 - val_mee_keras: 3.5245 - val_r2_keras: 0.9940
# Epoch 100/500
# 17/17 [==============================] - 0s 10ms/step - loss: 5.3149 - mean_squared_error: 2.9912 - mee_keras: 1.9848 - r2_keras: 0.9982 - val_loss: 12.3930 - val_mean_squared_error: 10.0667 - val_mee_keras: 3.4811 - val_r2_keras: 0.9938
# Epoch 101/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.3747 - mean_squared_error: 3.0468 - mee_keras: 1.9788 - r2_keras: 0.9981 - val_loss: 13.1200 - val_mean_squared_error: 10.7937 - val_mee_keras: 3.5289 - val_r2_keras: 0.9934
# Epoch 102/500
# 17/17 [==============================] - 0s 8ms/step - loss: 5.2726 - mean_squared_error: 2.9454 - mee_keras: 1.9649 - r2_keras: 0.9982 - val_loss: 12.0562 - val_mean_squared_error: 9.7318 - val_mee_keras: 3.3517 - val_r2_keras: 0.9941
# Epoch 103/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.5391 - mean_squared_error: 3.2096 - mee_keras: 2.0147 - r2_keras: 0.9980 - val_loss: 11.8500 - val_mean_squared_error: 9.5164 - val_mee_keras: 3.3580 - val_r2_keras: 0.9943
# Epoch 104/500
# 17/17 [==============================] - 0s 12ms/step - loss: 5.3174 - mean_squared_error: 2.9860 - mee_keras: 1.9583 - r2_keras: 0.9982 - val_loss: 11.9126 - val_mean_squared_error: 9.5829 - val_mee_keras: 3.3985 - val_r2_keras: 0.9942
# Epoch 105/500
# 17/17 [==============================] - 0s 12ms/step - loss: 5.3364 - mean_squared_error: 3.0072 - mee_keras: 1.9726 - r2_keras: 0.9982 - val_loss: 12.1713 - val_mean_squared_error: 9.8364 - val_mee_keras: 3.4183 - val_r2_keras: 0.9940
# Epoch 106/500
# 17/17 [==============================] - 0s 9ms/step - loss: 5.2542 - mean_squared_error: 2.9229 - mee_keras: 1.9726 - r2_keras: 0.9982 - val_loss: 11.5712 - val_mean_squared_error: 9.2353 - val_mee_keras: 3.2999 - val_r2_keras: 0.9944
# Epoch 107/500
# 17/17 [==============================] - 0s 11ms/step - loss: 5.3692 - mean_squared_error: 3.0339 - mee_keras: 1.9737 - r2_keras: 0.9981 - val_loss: 12.8932 - val_mean_squared_error: 10.5538 - val_mee_keras: 3.5262 - val_r2_keras: 0.9936

# %%
print('Best fold model:', best_fold)
print('Min MEE reached:', min_mee)
# Out:
# Best fold model: 15
# Min MEE reached: 2.1462738513946533

# %%
# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold - test set')
for i in range(0, len(loss_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - MSE: {mse_per_fold[i]} - MEE: {mee_per_fold[i]} - R2: {r2_per_fold[i]}')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> MSE: {np.mean(mse_per_fold)}')
print(f'> MEE: {np.mean(mee_per_fold)}')
print(f'> R2: {np.mean(r2_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold - test set
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 13.386879920959473 - MSE: 10.31549072265625 - MEE: 4.122493267059326 - R2: 0.9885332584381104
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 12.032327651977539 - MSE: 9.103776931762695 - MEE: 3.0004918575286865 - R2: 0.9949386715888977
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 7.181726932525635 - MSE: 4.452266693115234 - MEE: 2.283618927001953 - R2: 0.9976804852485657
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 6.647462368011475 - MSE: 3.9906041622161865 - MEE: 2.719625234603882 - R2: 0.9977055191993713
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 9.491347312927246 - MSE: 6.895543098449707 - MEE: 3.851884126663208 - R2: 0.9870865345001221
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 7.248180866241455 - MSE: 4.776989936828613 - MEE: 2.6464006900787354 - R2: 0.9973729252815247
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 7.649041652679443 - MSE: 5.183551788330078 - MEE: 2.1806602478027344 - R2: 0.997565746307373
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 8.738807678222656 - MSE: 6.300350666046143 - MEE: 2.3460307121276855 - R2: 0.9969528317451477
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 7.071944236755371 - MSE: 4.713747978210449 - MEE: 3.0582752227783203 - R2: 0.9966188073158264
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 7.4109320640563965 - MSE: 5.104049205780029 - MEE: 2.8596599102020264 - R2: 0.9940884709358215
# ------------------------------------------------------------------------
# > Fold 11 - Loss: 7.666088104248047 - MSE: 5.361818313598633 - MEE: 2.2108476161956787 - R2: 0.9972867369651794
# ------------------------------------------------------------------------
# > Fold 12 - Loss: 9.69679069519043 - MSE: 7.394763469696045 - MEE: 2.705308675765991 - R2: 0.9964861869812012
# ------------------------------------------------------------------------
# > Fold 13 - Loss: 7.1015305519104 - MSE: 4.779363632202148 - MEE: 2.6145105361938477 - R2: 0.9960453510284424
# ------------------------------------------------------------------------
# > Fold 14 - Loss: 9.420843124389648 - MSE: 7.100034713745117 - MEE: 2.949650764465332 - R2: 0.9959912300109863
# ------------------------------------------------------------------------
# > Fold 15 - Loss: 6.488584518432617 - MSE: 4.170134544372559 - MEE: 2.1462738513946533 - R2: 0.9978681206703186
# ------------------------------------------------------------------------
# > Fold 16 - Loss: 10.182952880859375 - MSE: 7.871870517730713 - MEE: 2.4174182415008545 - R2: 0.9962997436523438
# ------------------------------------------------------------------------
# > Fold 17 - Loss: 7.957259654998779 - MSE: 5.642861843109131 - MEE: 2.747338056564331 - R2: 0.9961287379264832
# ------------------------------------------------------------------------
# > Fold 18 - Loss: 8.205878257751465 - MSE: 5.881446838378906 - MEE: 2.645864248275757 - R2: 0.9970762133598328
# ------------------------------------------------------------------------
# > Fold 19 - Loss: 9.733654022216797 - MSE: 7.405864715576172 - MEE: 3.148643732070923 - R2: 0.9947867393493652
# ------------------------------------------------------------------------
# > Fold 20 - Loss: 6.683731555938721 - MSE: 4.3624162673950195 - MEE: 3.2553329467773438 - R2: 0.9935591220855713
# ------------------------------------------------------------------------
# Average scores for all folds:
# > MSE: 6.040347301959992
# > MEE: 2.7955164432525637
# > R2: 0.9955035716295242
# ------------------------------------------------------------------------

# %%
#plot of the first fold, that shows better the learning curve

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import numpy as np

plt.title('CUP - Model MSE result', fontsize=15)
plt.plot(list_of_history[0].history['mean_squared_error'], label='Train')
plt.plot(list_of_history[0].history['val_mean_squared_error'], label='Validation')
plt.xlabel('Cross-Validation Folds', fontsize=15)
plt.ylabel('MSE', fontsize=15)
plt.legend(fontsize=15)
plt.show()

#get a zoom of last 50 elements
plt.title('CUP - Model MSE result (zoom)', fontsize=15)
plt.plot(list_of_history[0].history['mean_squared_error'][-50:], label='Train')
plt.plot(list_of_history[0].history['val_mean_squared_error'][-50:], label='Validation')
plt.xlabel('Cross-Validation Folds', fontsize=15)
plt.ylabel('MSE', fontsize=15)
plt.legend(fontsize=15)
plt.show()

print('--- --- --- --- --- --- --- --- --- --- --- --- ---')

plt.title('CUP - Model MEE result', fontsize=15)
plt.plot(list_of_history[0].history['mee_keras'], label='Train')
plt.plot(list_of_history[0].history['val_mee_keras'], label='Validation')
plt.xlabel('Cross-Validation Folds', fontsize=15)
plt.ylabel('MEE', fontsize=15)
plt.legend(fontsize=15)
plt.show()

#get a zoom of last 50 elements
plt.title('CUP - Model MEE result (zoom)', fontsize=15)
plt.plot(list_of_history[0].history['mee_keras'][-50:], label='Train')
plt.plot(list_of_history[0].history['val_mee_keras'][-50:], label='Validation')
plt.xlabel('Cross-Validation Folds', fontsize=15)
plt.ylabel('MEE', fontsize=15)
plt.legend(fontsize=15)
plt.show()

print('--- --- --- --- --- --- --- --- --- --- --- --- ---')

#plot R2 value for each fold
plt.title('CUP - Model R2 result (zoom)', fontsize=15)
plt.plot(list_of_history[0].history['r2_keras'], label='Train')
plt.plot(list_of_history[0].history['val_r2_keras'], label='Validation')
plt.xlabel('Epochs', fontsize=15)
plt.ylabel('R2', fontsize=15)
plt.legend(fontsize=15)
plt.show()

plt.title('CUP - Model R2 result (zoom)', fontsize=15)
plt.plot(list_of_history[0].history['r2_keras'][-50:], label='Train')
plt.plot(list_of_history[0].history['val_r2_keras'][-50:], label='Validation')
plt.xlabel('Epochs', fontsize=15)
plt.ylabel('R2', fontsize=15)
plt.legend(fontsize=15)
plt.show()
# Out:
# --- --- --- --- --- --- --- --- --- --- --- --- ---
# --- --- --- --- --- --- --- --- --- --- --- --- ---

# %%
#plots of average values in CV

mean_val_loss = []
mean_train_loss = []

mean_val_mee = []
mean_train_mee = []

for i in range (num_folds):
  mean_val_loss.append(np.mean(list_of_history[i].history['val_mean_squared_error']))
  mean_train_loss.append(np.mean(list_of_history[i].history['mean_squared_error']))

  mean_val_mee.append(np.mean(list_of_history[i].history['val_mee_keras']))
  mean_train_mee.append(np.mean(list_of_history[i].history['mee_keras']))


plt.plot(mean_train_loss, label='Train')
plt.plot(mean_val_loss, label='Validation')
plt.xlabel('Cross-Validation Folds', fontsize=15)
plt.ylabel('MSE', fontsize=15)
plt.legend(fontsize=15)
plt.show()

plt.plot(mean_train_mee, label='Train')
plt.plot(mean_val_mee, label='Validation')
plt.xlabel('Cross-Validation Folds', fontsize=15)
plt.ylabel('MEE', fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# # Final testing

# %%
early_val_loss_test = EarlyStopping(
    monitor="val_loss",
    patience=150,
    min_delta=0.1,
    mode="min",
    restore_best_weights=True,
)

# %%
#retrain the best submodel using entire training set

history = submodel.fit(X_train, y_train, validation_split=0.10, batch_size=batch_size, epochs=30000, callbacks=[early_val_loss_test])
# Out:
# Epoch 1/30000
# 24/24 [==============================] - 0s 10ms/step - loss: 7.1810 - mean_squared_error: 4.8663 - mee_keras: 2.4337 - r2_keras: 0.9970 - val_loss: 10.5892 - val_mean_squared_error: 8.2727 - val_mee_keras: 3.2242 - val_r2_keras: 0.9949
# Epoch 2/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 7.0160 - mean_squared_error: 4.7045 - mee_keras: 2.3766 - r2_keras: 0.9972 - val_loss: 11.8773 - val_mean_squared_error: 9.5676 - val_mee_keras: 3.4417 - val_r2_keras: 0.9941
# Epoch 3/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.9238 - mean_squared_error: 4.6212 - mee_keras: 2.3520 - r2_keras: 0.9972 - val_loss: 10.7083 - val_mean_squared_error: 8.4036 - val_mee_keras: 3.2141 - val_r2_keras: 0.9947
# Epoch 4/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 7.1113 - mean_squared_error: 4.8120 - mee_keras: 2.3933 - r2_keras: 0.9971 - val_loss: 14.3652 - val_mean_squared_error: 12.0729 - val_mee_keras: 3.6730 - val_r2_keras: 0.9926
# Epoch 5/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.9207 - mean_squared_error: 4.6264 - mee_keras: 2.3393 - r2_keras: 0.9972 - val_loss: 11.5844 - val_mean_squared_error: 9.2902 - val_mee_keras: 3.4000 - val_r2_keras: 0.9942
# Epoch 6/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 7.0352 - mean_squared_error: 4.7462 - mee_keras: 2.3652 - r2_keras: 0.9971 - val_loss: 10.5312 - val_mean_squared_error: 8.2395 - val_mee_keras: 3.1193 - val_r2_keras: 0.9948
# Epoch 7/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.8785 - mean_squared_error: 4.5961 - mee_keras: 2.3611 - r2_keras: 0.9972 - val_loss: 10.8449 - val_mean_squared_error: 8.5633 - val_mee_keras: 3.2060 - val_r2_keras: 0.9947
# Epoch 8/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.9814 - mean_squared_error: 4.7030 - mee_keras: 2.3721 - r2_keras: 0.9971 - val_loss: 11.0780 - val_mean_squared_error: 8.7992 - val_mee_keras: 3.2539 - val_r2_keras: 0.9946
# Epoch 9/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.8043 - mean_squared_error: 4.5308 - mee_keras: 2.3896 - r2_keras: 0.9972 - val_loss: 10.5726 - val_mean_squared_error: 8.2980 - val_mee_keras: 3.1774 - val_r2_keras: 0.9948
# Epoch 10/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.9730 - mean_squared_error: 4.6987 - mee_keras: 2.3535 - r2_keras: 0.9971 - val_loss: 11.2013 - val_mean_squared_error: 8.9188 - val_mee_keras: 3.3576 - val_r2_keras: 0.9945
# Epoch 11/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.6900 - mean_squared_error: 4.4146 - mee_keras: 2.3529 - r2_keras: 0.9973 - val_loss: 12.0205 - val_mean_squared_error: 9.7539 - val_mee_keras: 3.5915 - val_r2_keras: 0.9940
# Epoch 12/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.6335 - mean_squared_error: 4.3667 - mee_keras: 2.3469 - r2_keras: 0.9973 - val_loss: 14.1867 - val_mean_squared_error: 11.9216 - val_mee_keras: 3.6661 - val_r2_keras: 0.9927
# Epoch 13/30000
# 24/24 [==============================] - 0s 7ms/step - loss: 6.8039 - mean_squared_error: 4.5367 - mee_keras: 2.3560 - r2_keras: 0.9972 - val_loss: 10.7550 - val_mean_squared_error: 8.4881 - val_mee_keras: 3.1205 - val_r2_keras: 0.9947
# Epoch 14/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.6224 - mean_squared_error: 4.3586 - mee_keras: 2.3442 - r2_keras: 0.9974 - val_loss: 10.4827 - val_mean_squared_error: 8.2170 - val_mee_keras: 3.1202 - val_r2_keras: 0.9949
# Epoch 15/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.7867 - mean_squared_error: 4.5281 - mee_keras: 2.3481 - r2_keras: 0.9973 - val_loss: 12.5061 - val_mean_squared_error: 10.2472 - val_mee_keras: 3.5337 - val_r2_keras: 0.9936
# Epoch 16/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.8407 - mean_squared_error: 4.5865 - mee_keras: 2.3841 - r2_keras: 0.9972 - val_loss: 12.0676 - val_mean_squared_error: 9.8280 - val_mee_keras: 3.4049 - val_r2_keras: 0.9940
# Epoch 17/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.7814 - mean_squared_error: 4.5369 - mee_keras: 2.3689 - r2_keras: 0.9973 - val_loss: 12.0500 - val_mean_squared_error: 9.8086 - val_mee_keras: 3.5151 - val_r2_keras: 0.9940
# Epoch 18/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.8092 - mean_squared_error: 4.5714 - mee_keras: 2.3869 - r2_keras: 0.9972 - val_loss: 13.4977 - val_mean_squared_error: 11.2620 - val_mee_keras: 3.4701 - val_r2_keras: 0.9931
# Epoch 19/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.7428 - mean_squared_error: 4.5090 - mee_keras: 2.3816 - r2_keras: 0.9972 - val_loss: 10.4053 - val_mean_squared_error: 8.1657 - val_mee_keras: 3.0994 - val_r2_keras: 0.9949
# Epoch 20/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.6399 - mean_squared_error: 4.4043 - mee_keras: 2.3389 - r2_keras: 0.9973 - val_loss: 12.4250 - val_mean_squared_error: 10.1900 - val_mee_keras: 3.3959 - val_r2_keras: 0.9938
# Epoch 21/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.5754 - mean_squared_error: 4.3426 - mee_keras: 2.3044 - r2_keras: 0.9974 - val_loss: 10.5832 - val_mean_squared_error: 8.3495 - val_mee_keras: 3.2096 - val_r2_keras: 0.9947
# Epoch 22/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.6963 - mean_squared_error: 4.4649 - mee_keras: 2.3111 - r2_keras: 0.9973 - val_loss: 12.7745 - val_mean_squared_error: 10.5441 - val_mee_keras: 3.4803 - val_r2_keras: 0.9936
# Epoch 23/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.4841 - mean_squared_error: 4.2530 - mee_keras: 2.2909 - r2_keras: 0.9974 - val_loss: 10.8041 - val_mean_squared_error: 8.5678 - val_mee_keras: 3.2311 - val_r2_keras: 0.9946
# Epoch 24/30000
# 24/24 [==============================] - 0s 7ms/step - loss: 6.5767 - mean_squared_error: 4.3442 - mee_keras: 2.2873 - r2_keras: 0.9974 - val_loss: 10.8631 - val_mean_squared_error: 8.6312 - val_mee_keras: 3.1777 - val_r2_keras: 0.9947
# Epoch 25/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 7.0011 - mean_squared_error: 4.7696 - mee_keras: 2.3835 - r2_keras: 0.9970 - val_loss: 11.7435 - val_mean_squared_error: 9.5077 - val_mee_keras: 3.3024 - val_r2_keras: 0.9942
# Epoch 26/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.4454 - mean_squared_error: 4.2148 - mee_keras: 2.3155 - r2_keras: 0.9974 - val_loss: 11.1664 - val_mean_squared_error: 8.9317 - val_mee_keras: 3.2392 - val_r2_keras: 0.9944
# Epoch 27/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.5204 - mean_squared_error: 4.2899 - mee_keras: 2.3580 - r2_keras: 0.9973 - val_loss: 10.6546 - val_mean_squared_error: 8.4192 - val_mee_keras: 3.1689 - val_r2_keras: 0.9948
# Epoch 28/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.8498 - mean_squared_error: 4.6168 - mee_keras: 2.3951 - r2_keras: 0.9972 - val_loss: 11.8145 - val_mean_squared_error: 9.5874 - val_mee_keras: 3.3883 - val_r2_keras: 0.9941
# Epoch 29/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.4745 - mean_squared_error: 4.2469 - mee_keras: 2.2989 - r2_keras: 0.9974 - val_loss: 10.6396 - val_mean_squared_error: 8.4136 - val_mee_keras: 3.0513 - val_r2_keras: 0.9947
# Epoch 30/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.5744 - mean_squared_error: 4.3554 - mee_keras: 2.3535 - r2_keras: 0.9973 - val_loss: 11.2348 - val_mean_squared_error: 9.0167 - val_mee_keras: 3.3019 - val_r2_keras: 0.9944
# Epoch 31/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.6246 - mean_squared_error: 4.4022 - mee_keras: 2.3497 - r2_keras: 0.9973 - val_loss: 11.0130 - val_mean_squared_error: 8.7913 - val_mee_keras: 3.1916 - val_r2_keras: 0.9945
# Epoch 32/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.5975 - mean_squared_error: 4.3771 - mee_keras: 2.3384 - r2_keras: 0.9973 - val_loss: 13.1463 - val_mean_squared_error: 10.9244 - val_mee_keras: 3.4740 - val_r2_keras: 0.9933
# Epoch 33/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.7054 - mean_squared_error: 4.4831 - mee_keras: 2.3962 - r2_keras: 0.9973 - val_loss: 11.4203 - val_mean_squared_error: 9.2027 - val_mee_keras: 3.2242 - val_r2_keras: 0.9943
# Epoch 34/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.6553 - mean_squared_error: 4.4399 - mee_keras: 2.2976 - r2_keras: 0.9973 - val_loss: 10.8918 - val_mean_squared_error: 8.6718 - val_mee_keras: 3.1999 - val_r2_keras: 0.9946
# Epoch 35/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.5029 - mean_squared_error: 4.2838 - mee_keras: 2.3268 - r2_keras: 0.9974 - val_loss: 13.1138 - val_mean_squared_error: 10.8965 - val_mee_keras: 3.5278 - val_r2_keras: 0.9933
# Epoch 36/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.4733 - mean_squared_error: 4.2527 - mee_keras: 2.2995 - r2_keras: 0.9974 - val_loss: 10.3370 - val_mean_squared_error: 8.1152 - val_mee_keras: 3.0527 - val_r2_keras: 0.9949
# Epoch 37/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.6664 - mean_squared_error: 4.4517 - mee_keras: 2.3312 - r2_keras: 0.9973 - val_loss: 13.5844 - val_mean_squared_error: 11.3749 - val_mee_keras: 3.7421 - val_r2_keras: 0.9930
# Epoch 38/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.5792 - mean_squared_error: 4.3681 - mee_keras: 2.3754 - r2_keras: 0.9973 - val_loss: 11.4260 - val_mean_squared_error: 9.2129 - val_mee_keras: 3.3049 - val_r2_keras: 0.9943
# Epoch 39/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.4966 - mean_squared_error: 4.2901 - mee_keras: 2.3256 - r2_keras: 0.9974 - val_loss: 11.2369 - val_mean_squared_error: 9.0296 - val_mee_keras: 3.2255 - val_r2_keras: 0.9943
# Epoch 40/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.5514 - mean_squared_error: 4.3507 - mee_keras: 2.3216 - r2_keras: 0.9973 - val_loss: 11.6911 - val_mean_squared_error: 9.4911 - val_mee_keras: 3.2954 - val_r2_keras: 0.9942
# Epoch 41/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.6146 - mean_squared_error: 4.4148 - mee_keras: 2.3563 - r2_keras: 0.9973 - val_loss: 11.0768 - val_mean_squared_error: 8.8766 - val_mee_keras: 3.2422 - val_r2_keras: 0.9945
# Epoch 42/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.6243 - mean_squared_error: 4.4239 - mee_keras: 2.3391 - r2_keras: 0.9973 - val_loss: 10.8157 - val_mean_squared_error: 8.6096 - val_mee_keras: 3.2171 - val_r2_keras: 0.9946
# Epoch 43/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.5848 - mean_squared_error: 4.3826 - mee_keras: 2.2955 - r2_keras: 0.9973 - val_loss: 12.5065 - val_mean_squared_error: 10.3168 - val_mee_keras: 3.5786 - val_r2_keras: 0.9937
# Epoch 44/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.5107 - mean_squared_error: 4.3169 - mee_keras: 2.3405 - r2_keras: 0.9974 - val_loss: 12.0303 - val_mean_squared_error: 9.8428 - val_mee_keras: 3.3042 - val_r2_keras: 0.9940
# Epoch 45/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.5445 - mean_squared_error: 4.3515 - mee_keras: 2.3320 - r2_keras: 0.9973 - val_loss: 10.2794 - val_mean_squared_error: 8.0840 - val_mee_keras: 3.0502 - val_r2_keras: 0.9950
# Epoch 46/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.4396 - mean_squared_error: 4.2416 - mee_keras: 2.2907 - r2_keras: 0.9974 - val_loss: 13.8765 - val_mean_squared_error: 11.6802 - val_mee_keras: 3.6330 - val_r2_keras: 0.9929
# Epoch 47/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.6507 - mean_squared_error: 4.4494 - mee_keras: 2.3463 - r2_keras: 0.9973 - val_loss: 10.5172 - val_mean_squared_error: 8.3093 - val_mee_keras: 3.0320 - val_r2_keras: 0.9948
# Epoch 48/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.4516 - mean_squared_error: 4.2438 - mee_keras: 2.3058 - r2_keras: 0.9974 - val_loss: 11.9873 - val_mean_squared_error: 9.7812 - val_mee_keras: 3.4314 - val_r2_keras: 0.9940
# Epoch 49/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.6342 - mean_squared_error: 4.4269 - mee_keras: 2.3190 - r2_keras: 0.9973 - val_loss: 11.0106 - val_mean_squared_error: 8.8038 - val_mee_keras: 3.1603 - val_r2_keras: 0.9945
# Epoch 50/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.4551 - mean_squared_error: 4.2498 - mee_keras: 2.2810 - r2_keras: 0.9974 - val_loss: 11.7227 - val_mean_squared_error: 9.5186 - val_mee_keras: 3.3085 - val_r2_keras: 0.9942
# Epoch 51/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.4213 - mean_squared_error: 4.2169 - mee_keras: 2.3430 - r2_keras: 0.9974 - val_loss: 12.0880 - val_mean_squared_error: 9.8920 - val_mee_keras: 3.5015 - val_r2_keras: 0.9939
# Epoch 52/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.5399 - mean_squared_error: 4.3390 - mee_keras: 2.3171 - r2_keras: 0.9974 - val_loss: 11.0986 - val_mean_squared_error: 8.8931 - val_mee_keras: 3.2678 - val_r2_keras: 0.9945
# Epoch 53/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.3223 - mean_squared_error: 4.1210 - mee_keras: 2.2969 - r2_keras: 0.9975 - val_loss: 10.8729 - val_mean_squared_error: 8.6648 - val_mee_keras: 3.1492 - val_r2_keras: 0.9946
# Epoch 54/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3719 - mean_squared_error: 4.1684 - mee_keras: 2.2897 - r2_keras: 0.9975 - val_loss: 11.5271 - val_mean_squared_error: 9.3212 - val_mee_keras: 3.2936 - val_r2_keras: 0.9943
# Epoch 55/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.6202 - mean_squared_error: 4.4187 - mee_keras: 2.3034 - r2_keras: 0.9973 - val_loss: 11.9964 - val_mean_squared_error: 9.7935 - val_mee_keras: 3.3561 - val_r2_keras: 0.9940
# Epoch 56/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.5502 - mean_squared_error: 4.3501 - mee_keras: 2.3184 - r2_keras: 0.9974 - val_loss: 12.8085 - val_mean_squared_error: 10.6133 - val_mee_keras: 3.5152 - val_r2_keras: 0.9935
# Epoch 57/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.4985 - mean_squared_error: 4.2989 - mee_keras: 2.3216 - r2_keras: 0.9974 - val_loss: 11.1439 - val_mean_squared_error: 8.9379 - val_mee_keras: 3.2531 - val_r2_keras: 0.9944
# Epoch 58/30000
# 24/24 [==============================] - 0s 7ms/step - loss: 6.2711 - mean_squared_error: 4.0723 - mee_keras: 2.2932 - r2_keras: 0.9975 - val_loss: 11.0363 - val_mean_squared_error: 8.8344 - val_mee_keras: 3.2324 - val_r2_keras: 0.9945
# Epoch 59/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.4892 - mean_squared_error: 4.2902 - mee_keras: 2.3124 - r2_keras: 0.9974 - val_loss: 16.2597 - val_mean_squared_error: 14.0656 - val_mee_keras: 4.0270 - val_r2_keras: 0.9915
# Epoch 60/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.4084 - mean_squared_error: 4.2069 - mee_keras: 2.3232 - r2_keras: 0.9974 - val_loss: 10.9059 - val_mean_squared_error: 8.6974 - val_mee_keras: 3.1712 - val_r2_keras: 0.9945
# Epoch 61/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.4620 - mean_squared_error: 4.2596 - mee_keras: 2.3112 - r2_keras: 0.9974 - val_loss: 11.3902 - val_mean_squared_error: 9.1930 - val_mee_keras: 3.3146 - val_r2_keras: 0.9943
# Epoch 62/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3907 - mean_squared_error: 4.1953 - mee_keras: 2.3272 - r2_keras: 0.9974 - val_loss: 11.5070 - val_mean_squared_error: 9.3152 - val_mee_keras: 3.2951 - val_r2_keras: 0.9942
# Epoch 63/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3337 - mean_squared_error: 4.1506 - mee_keras: 2.3112 - r2_keras: 0.9975 - val_loss: 11.2744 - val_mean_squared_error: 9.0879 - val_mee_keras: 3.2092 - val_r2_keras: 0.9943
# Epoch 64/30000
# 24/24 [==============================] - 0s 7ms/step - loss: 6.4631 - mean_squared_error: 4.2800 - mee_keras: 2.3010 - r2_keras: 0.9974 - val_loss: 11.9630 - val_mean_squared_error: 9.7823 - val_mee_keras: 3.4481 - val_r2_keras: 0.9940
# Epoch 65/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3199 - mean_squared_error: 4.1335 - mee_keras: 2.2660 - r2_keras: 0.9975 - val_loss: 11.6399 - val_mean_squared_error: 9.4552 - val_mee_keras: 3.4670 - val_r2_keras: 0.9941
# Epoch 66/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.4852 - mean_squared_error: 4.2969 - mee_keras: 2.3247 - r2_keras: 0.9974 - val_loss: 11.2783 - val_mean_squared_error: 9.0903 - val_mee_keras: 3.2841 - val_r2_keras: 0.9943
# Epoch 67/30000
# 24/24 [==============================] - 0s 7ms/step - loss: 6.3366 - mean_squared_error: 4.1474 - mee_keras: 2.2819 - r2_keras: 0.9975 - val_loss: 11.2267 - val_mean_squared_error: 9.0344 - val_mee_keras: 3.2393 - val_r2_keras: 0.9943
# Epoch 68/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3497 - mean_squared_error: 4.1622 - mee_keras: 2.2527 - r2_keras: 0.9975 - val_loss: 13.3434 - val_mean_squared_error: 11.1574 - val_mee_keras: 3.4353 - val_r2_keras: 0.9932
# Epoch 69/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.4712 - mean_squared_error: 4.2797 - mee_keras: 2.2968 - r2_keras: 0.9974 - val_loss: 11.0013 - val_mean_squared_error: 8.8073 - val_mee_keras: 3.2562 - val_r2_keras: 0.9945
# Epoch 70/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.4080 - mean_squared_error: 4.2171 - mee_keras: 2.2877 - r2_keras: 0.9974 - val_loss: 11.5206 - val_mean_squared_error: 9.3328 - val_mee_keras: 3.3288 - val_r2_keras: 0.9943
# Epoch 71/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.3736 - mean_squared_error: 4.1836 - mee_keras: 2.2730 - r2_keras: 0.9975 - val_loss: 14.3292 - val_mean_squared_error: 12.1448 - val_mee_keras: 3.6513 - val_r2_keras: 0.9926
# Epoch 72/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.4769 - mean_squared_error: 4.2895 - mee_keras: 2.3217 - r2_keras: 0.9974 - val_loss: 11.1711 - val_mean_squared_error: 8.9808 - val_mee_keras: 3.3401 - val_r2_keras: 0.9944
# Epoch 73/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.5834 - mean_squared_error: 4.3923 - mee_keras: 2.3284 - r2_keras: 0.9973 - val_loss: 12.7174 - val_mean_squared_error: 10.5252 - val_mee_keras: 3.4176 - val_r2_keras: 0.9935
# Epoch 74/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.3941 - mean_squared_error: 4.2004 - mee_keras: 2.2610 - r2_keras: 0.9974 - val_loss: 11.5510 - val_mean_squared_error: 9.3590 - val_mee_keras: 3.2474 - val_r2_keras: 0.9942
# Epoch 75/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.4262 - mean_squared_error: 4.2290 - mee_keras: 2.2842 - r2_keras: 0.9974 - val_loss: 12.0926 - val_mean_squared_error: 9.8938 - val_mee_keras: 3.3654 - val_r2_keras: 0.9939
# Epoch 76/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2866 - mean_squared_error: 4.0880 - mee_keras: 2.3013 - r2_keras: 0.9975 - val_loss: 11.3340 - val_mean_squared_error: 9.1373 - val_mee_keras: 3.2622 - val_r2_keras: 0.9944
# Epoch 77/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.4864 - mean_squared_error: 4.2875 - mee_keras: 2.2858 - r2_keras: 0.9974 - val_loss: 11.1781 - val_mean_squared_error: 8.9773 - val_mee_keras: 3.3117 - val_r2_keras: 0.9944
# Epoch 78/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.4815 - mean_squared_error: 4.2728 - mee_keras: 2.3168 - r2_keras: 0.9974 - val_loss: 11.8146 - val_mean_squared_error: 9.6090 - val_mee_keras: 3.2579 - val_r2_keras: 0.9941
# Epoch 79/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3153 - mean_squared_error: 4.1056 - mee_keras: 2.2780 - r2_keras: 0.9975 - val_loss: 10.9429 - val_mean_squared_error: 8.7257 - val_mee_keras: 3.1720 - val_r2_keras: 0.9945
# Epoch 80/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.4672 - mean_squared_error: 4.2529 - mee_keras: 2.2970 - r2_keras: 0.9974 - val_loss: 12.5606 - val_mean_squared_error: 10.3509 - val_mee_keras: 3.6070 - val_r2_keras: 0.9936
# Epoch 81/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.2554 - mean_squared_error: 4.0374 - mee_keras: 2.2640 - r2_keras: 0.9976 - val_loss: 10.5983 - val_mean_squared_error: 8.3728 - val_mee_keras: 3.1832 - val_r2_keras: 0.9948
# Epoch 82/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.2991 - mean_squared_error: 4.0752 - mee_keras: 2.2535 - r2_keras: 0.9975 - val_loss: 12.6734 - val_mean_squared_error: 10.4537 - val_mee_keras: 3.4981 - val_r2_keras: 0.9936
# Epoch 83/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.5130 - mean_squared_error: 4.2868 - mee_keras: 2.3100 - r2_keras: 0.9974 - val_loss: 11.0615 - val_mean_squared_error: 8.8327 - val_mee_keras: 3.2305 - val_r2_keras: 0.9945
# Epoch 84/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.2809 - mean_squared_error: 4.0519 - mee_keras: 2.2967 - r2_keras: 0.9975 - val_loss: 11.9273 - val_mean_squared_error: 9.6984 - val_mee_keras: 3.4057 - val_r2_keras: 0.9940
# Epoch 85/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3327 - mean_squared_error: 4.1040 - mee_keras: 2.2849 - r2_keras: 0.9975 - val_loss: 11.5913 - val_mean_squared_error: 9.3598 - val_mee_keras: 3.2697 - val_r2_keras: 0.9942
# Epoch 86/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2893 - mean_squared_error: 4.0637 - mee_keras: 2.2400 - r2_keras: 0.9975 - val_loss: 11.3420 - val_mean_squared_error: 9.1098 - val_mee_keras: 3.2845 - val_r2_keras: 0.9943
# Epoch 87/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.2625 - mean_squared_error: 4.0312 - mee_keras: 2.2688 - r2_keras: 0.9976 - val_loss: 12.2188 - val_mean_squared_error: 9.9869 - val_mee_keras: 3.3134 - val_r2_keras: 0.9939
# Epoch 88/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2486 - mean_squared_error: 4.0195 - mee_keras: 2.2351 - r2_keras: 0.9976 - val_loss: 13.2659 - val_mean_squared_error: 11.0453 - val_mee_keras: 3.5098 - val_r2_keras: 0.9932
# Epoch 89/30000
# 24/24 [==============================] - 0s 10ms/step - loss: 6.2435 - mean_squared_error: 4.0213 - mee_keras: 2.2431 - r2_keras: 0.9976 - val_loss: 12.5334 - val_mean_squared_error: 10.3105 - val_mee_keras: 3.4903 - val_r2_keras: 0.9937
# Epoch 90/30000
# 24/24 [==============================] - 0s 10ms/step - loss: 6.3992 - mean_squared_error: 4.1726 - mee_keras: 2.2723 - r2_keras: 0.9975 - val_loss: 11.5076 - val_mean_squared_error: 9.2745 - val_mee_keras: 3.2397 - val_r2_keras: 0.9941
# Epoch 91/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.3253 - mean_squared_error: 4.0975 - mee_keras: 2.2723 - r2_keras: 0.9975 - val_loss: 12.2553 - val_mean_squared_error: 10.0212 - val_mee_keras: 3.3412 - val_r2_keras: 0.9936
# Epoch 92/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1405 - mean_squared_error: 3.9185 - mee_keras: 2.2323 - r2_keras: 0.9976 - val_loss: 11.1315 - val_mean_squared_error: 8.9142 - val_mee_keras: 3.3746 - val_r2_keras: 0.9943
# Epoch 93/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3659 - mean_squared_error: 4.1463 - mee_keras: 2.2869 - r2_keras: 0.9975 - val_loss: 13.2870 - val_mean_squared_error: 11.0685 - val_mee_keras: 3.4600 - val_r2_keras: 0.9932
# Epoch 94/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.3992 - mean_squared_error: 4.1756 - mee_keras: 2.2773 - r2_keras: 0.9975 - val_loss: 13.2880 - val_mean_squared_error: 11.0664 - val_mee_keras: 3.4962 - val_r2_keras: 0.9933
# Epoch 95/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1441 - mean_squared_error: 3.9207 - mee_keras: 2.2380 - r2_keras: 0.9976 - val_loss: 11.9834 - val_mean_squared_error: 9.7568 - val_mee_keras: 3.3207 - val_r2_keras: 0.9940
# Epoch 96/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1599 - mean_squared_error: 3.9340 - mee_keras: 2.2475 - r2_keras: 0.9976 - val_loss: 11.7585 - val_mean_squared_error: 9.5396 - val_mee_keras: 3.4229 - val_r2_keras: 0.9941
# Epoch 97/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.1565 - mean_squared_error: 3.9357 - mee_keras: 2.2287 - r2_keras: 0.9976 - val_loss: 11.8000 - val_mean_squared_error: 9.5793 - val_mee_keras: 3.3838 - val_r2_keras: 0.9941
# Epoch 98/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.4396 - mean_squared_error: 4.2223 - mee_keras: 2.3244 - r2_keras: 0.9974 - val_loss: 10.9175 - val_mean_squared_error: 8.6958 - val_mee_keras: 3.1843 - val_r2_keras: 0.9946
# Epoch 99/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2147 - mean_squared_error: 3.9944 - mee_keras: 2.2676 - r2_keras: 0.9976 - val_loss: 11.0785 - val_mean_squared_error: 8.8606 - val_mee_keras: 3.2462 - val_r2_keras: 0.9945
# Epoch 100/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2137 - mean_squared_error: 3.9940 - mee_keras: 2.2720 - r2_keras: 0.9975 - val_loss: 11.2453 - val_mean_squared_error: 9.0219 - val_mee_keras: 3.2769 - val_r2_keras: 0.9944
# Epoch 101/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3044 - mean_squared_error: 4.0846 - mee_keras: 2.2847 - r2_keras: 0.9975 - val_loss: 11.3131 - val_mean_squared_error: 9.0901 - val_mee_keras: 3.2383 - val_r2_keras: 0.9943
# Epoch 102/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3961 - mean_squared_error: 4.1772 - mee_keras: 2.2934 - r2_keras: 0.9975 - val_loss: 10.7382 - val_mean_squared_error: 8.5179 - val_mee_keras: 3.0715 - val_r2_keras: 0.9947
# Epoch 103/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3296 - mean_squared_error: 4.1072 - mee_keras: 2.2588 - r2_keras: 0.9975 - val_loss: 13.1137 - val_mean_squared_error: 10.8925 - val_mee_keras: 3.4619 - val_r2_keras: 0.9933
# Epoch 104/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.1826 - mean_squared_error: 3.9547 - mee_keras: 2.2286 - r2_keras: 0.9976 - val_loss: 11.2973 - val_mean_squared_error: 9.0683 - val_mee_keras: 3.2947 - val_r2_keras: 0.9943
# Epoch 105/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1911 - mean_squared_error: 3.9662 - mee_keras: 2.2547 - r2_keras: 0.9976 - val_loss: 10.8810 - val_mean_squared_error: 8.6478 - val_mee_keras: 3.2804 - val_r2_keras: 0.9946
# Epoch 106/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1323 - mean_squared_error: 3.9042 - mee_keras: 2.2051 - r2_keras: 0.9976 - val_loss: 11.2699 - val_mean_squared_error: 9.0385 - val_mee_keras: 3.2420 - val_r2_keras: 0.9943
# Epoch 107/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2413 - mean_squared_error: 4.0168 - mee_keras: 2.2351 - r2_keras: 0.9976 - val_loss: 11.9559 - val_mean_squared_error: 9.7325 - val_mee_keras: 3.3206 - val_r2_keras: 0.9940
# Epoch 108/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3865 - mean_squared_error: 4.1617 - mee_keras: 2.2907 - r2_keras: 0.9975 - val_loss: 11.4784 - val_mean_squared_error: 9.2529 - val_mee_keras: 3.4041 - val_r2_keras: 0.9943
# Epoch 109/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2315 - mean_squared_error: 4.0074 - mee_keras: 2.2649 - r2_keras: 0.9976 - val_loss: 14.3358 - val_mean_squared_error: 12.1156 - val_mee_keras: 3.6346 - val_r2_keras: 0.9926
# Epoch 110/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.0973 - mean_squared_error: 3.8714 - mee_keras: 2.2291 - r2_keras: 0.9976 - val_loss: 12.3051 - val_mean_squared_error: 10.0810 - val_mee_keras: 3.4904 - val_r2_keras: 0.9938
# Epoch 111/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 5.9943 - mean_squared_error: 3.7722 - mee_keras: 2.2019 - r2_keras: 0.9977 - val_loss: 12.1113 - val_mean_squared_error: 9.8942 - val_mee_keras: 3.4612 - val_r2_keras: 0.9939
# Epoch 112/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.0789 - mean_squared_error: 3.8578 - mee_keras: 2.2229 - r2_keras: 0.9977 - val_loss: 12.7352 - val_mean_squared_error: 10.5188 - val_mee_keras: 3.4671 - val_r2_keras: 0.9935
# Epoch 113/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2152 - mean_squared_error: 3.9914 - mee_keras: 2.2234 - r2_keras: 0.9975 - val_loss: 11.8414 - val_mean_squared_error: 9.6032 - val_mee_keras: 3.2365 - val_r2_keras: 0.9939
# Epoch 114/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.2851 - mean_squared_error: 4.0537 - mee_keras: 2.2479 - r2_keras: 0.9975 - val_loss: 12.9107 - val_mean_squared_error: 10.6845 - val_mee_keras: 3.4107 - val_r2_keras: 0.9935
# Epoch 115/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.2224 - mean_squared_error: 3.9929 - mee_keras: 2.2525 - r2_keras: 0.9976 - val_loss: 13.7250 - val_mean_squared_error: 11.5022 - val_mee_keras: 3.6664 - val_r2_keras: 0.9930
# Epoch 116/30000
# 24/24 [==============================] - 0s 7ms/step - loss: 6.2135 - mean_squared_error: 3.9840 - mee_keras: 2.2290 - r2_keras: 0.9976 - val_loss: 12.7651 - val_mean_squared_error: 10.5374 - val_mee_keras: 3.5134 - val_r2_keras: 0.9935
# Epoch 117/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1251 - mean_squared_error: 3.8936 - mee_keras: 2.2258 - r2_keras: 0.9976 - val_loss: 14.0983 - val_mean_squared_error: 11.8695 - val_mee_keras: 3.7491 - val_r2_keras: 0.9928
# Epoch 118/30000
# 24/24 [==============================] - 0s 7ms/step - loss: 6.2304 - mean_squared_error: 3.9940 - mee_keras: 2.2455 - r2_keras: 0.9976 - val_loss: 12.6600 - val_mean_squared_error: 10.4265 - val_mee_keras: 3.4085 - val_r2_keras: 0.9936
# Epoch 119/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.3138 - mean_squared_error: 4.0759 - mee_keras: 2.2263 - r2_keras: 0.9975 - val_loss: 11.2857 - val_mean_squared_error: 9.0424 - val_mee_keras: 3.3057 - val_r2_keras: 0.9944
# Epoch 120/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3260 - mean_squared_error: 4.0907 - mee_keras: 2.2878 - r2_keras: 0.9975 - val_loss: 12.7843 - val_mean_squared_error: 10.5509 - val_mee_keras: 3.3945 - val_r2_keras: 0.9935
# Epoch 121/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3646 - mean_squared_error: 4.1248 - mee_keras: 2.2414 - r2_keras: 0.9975 - val_loss: 11.4545 - val_mean_squared_error: 9.2161 - val_mee_keras: 3.2557 - val_r2_keras: 0.9943
# Epoch 122/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.2603 - mean_squared_error: 4.0181 - mee_keras: 2.2563 - r2_keras: 0.9976 - val_loss: 14.7963 - val_mean_squared_error: 12.5610 - val_mee_keras: 3.8517 - val_r2_keras: 0.9923
# Epoch 123/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.3624 - mean_squared_error: 4.1208 - mee_keras: 2.2500 - r2_keras: 0.9975 - val_loss: 12.2647 - val_mean_squared_error: 10.0218 - val_mee_keras: 3.3717 - val_r2_keras: 0.9939
# Epoch 124/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1539 - mean_squared_error: 3.9093 - mee_keras: 2.2414 - r2_keras: 0.9976 - val_loss: 13.6482 - val_mean_squared_error: 11.4072 - val_mee_keras: 3.6188 - val_r2_keras: 0.9930
# Epoch 125/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.0666 - mean_squared_error: 3.8229 - mee_keras: 2.2208 - r2_keras: 0.9977 - val_loss: 12.3263 - val_mean_squared_error: 10.0861 - val_mee_keras: 3.4636 - val_r2_keras: 0.9938
# Epoch 126/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.0243 - mean_squared_error: 3.7802 - mee_keras: 2.2110 - r2_keras: 0.9977 - val_loss: 11.0435 - val_mean_squared_error: 8.7932 - val_mee_keras: 3.2043 - val_r2_keras: 0.9945
# Epoch 127/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3180 - mean_squared_error: 4.0731 - mee_keras: 2.2581 - r2_keras: 0.9975 - val_loss: 11.5373 - val_mean_squared_error: 9.2880 - val_mee_keras: 3.2119 - val_r2_keras: 0.9942
# Epoch 128/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2079 - mean_squared_error: 3.9594 - mee_keras: 2.2365 - r2_keras: 0.9976 - val_loss: 12.6420 - val_mean_squared_error: 10.3986 - val_mee_keras: 3.4353 - val_r2_keras: 0.9936
# Epoch 129/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.0876 - mean_squared_error: 3.8383 - mee_keras: 2.1849 - r2_keras: 0.9977 - val_loss: 11.7559 - val_mean_squared_error: 9.5110 - val_mee_keras: 3.3439 - val_r2_keras: 0.9941
# Epoch 130/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2709 - mean_squared_error: 4.0248 - mee_keras: 2.2412 - r2_keras: 0.9976 - val_loss: 12.0943 - val_mean_squared_error: 9.8472 - val_mee_keras: 3.3864 - val_r2_keras: 0.9939
# Epoch 131/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1056 - mean_squared_error: 3.8549 - mee_keras: 2.2146 - r2_keras: 0.9977 - val_loss: 11.8355 - val_mean_squared_error: 9.5929 - val_mee_keras: 3.4010 - val_r2_keras: 0.9941
# Epoch 132/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.2641 - mean_squared_error: 4.0148 - mee_keras: 2.2452 - r2_keras: 0.9976 - val_loss: 11.0981 - val_mean_squared_error: 8.8411 - val_mee_keras: 3.2895 - val_r2_keras: 0.9944
# Epoch 133/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.2140 - mean_squared_error: 3.9620 - mee_keras: 2.2591 - r2_keras: 0.9976 - val_loss: 11.1408 - val_mean_squared_error: 8.8806 - val_mee_keras: 3.1845 - val_r2_keras: 0.9944
# Epoch 134/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2443 - mean_squared_error: 3.9906 - mee_keras: 2.2475 - r2_keras: 0.9976 - val_loss: 11.4744 - val_mean_squared_error: 9.2196 - val_mee_keras: 3.2218 - val_r2_keras: 0.9941
# Epoch 135/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.0527 - mean_squared_error: 3.8019 - mee_keras: 2.2056 - r2_keras: 0.9977 - val_loss: 11.1595 - val_mean_squared_error: 8.9116 - val_mee_keras: 3.2837 - val_r2_keras: 0.9944
# Epoch 136/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.3806 - mean_squared_error: 4.1278 - mee_keras: 2.2838 - r2_keras: 0.9975 - val_loss: 14.4123 - val_mean_squared_error: 12.1587 - val_mee_keras: 3.6166 - val_r2_keras: 0.9926
# Epoch 137/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.1696 - mean_squared_error: 3.9121 - mee_keras: 2.2051 - r2_keras: 0.9976 - val_loss: 11.4214 - val_mean_squared_error: 9.1622 - val_mee_keras: 3.3220 - val_r2_keras: 0.9943
# Epoch 138/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2317 - mean_squared_error: 3.9731 - mee_keras: 2.2429 - r2_keras: 0.9976 - val_loss: 14.2798 - val_mean_squared_error: 12.0277 - val_mee_keras: 3.6385 - val_r2_keras: 0.9927
# Epoch 139/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.0501 - mean_squared_error: 3.7930 - mee_keras: 2.1702 - r2_keras: 0.9977 - val_loss: 11.8121 - val_mean_squared_error: 9.5460 - val_mee_keras: 3.3059 - val_r2_keras: 0.9939
# Epoch 140/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.0951 - mean_squared_error: 3.8335 - mee_keras: 2.2271 - r2_keras: 0.9976 - val_loss: 13.1816 - val_mean_squared_error: 10.9255 - val_mee_keras: 3.4652 - val_r2_keras: 0.9933
# Epoch 141/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.1009 - mean_squared_error: 3.8385 - mee_keras: 2.2053 - r2_keras: 0.9977 - val_loss: 11.6150 - val_mean_squared_error: 9.3450 - val_mee_keras: 3.3030 - val_r2_keras: 0.9941
# Epoch 142/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1663 - mean_squared_error: 3.9006 - mee_keras: 2.2155 - r2_keras: 0.9976 - val_loss: 13.9209 - val_mean_squared_error: 11.6608 - val_mee_keras: 3.5968 - val_r2_keras: 0.9928
# Epoch 143/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.1413 - mean_squared_error: 3.8818 - mee_keras: 2.2091 - r2_keras: 0.9976 - val_loss: 12.4833 - val_mean_squared_error: 10.2254 - val_mee_keras: 3.4857 - val_r2_keras: 0.9937
# Epoch 144/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2433 - mean_squared_error: 3.9867 - mee_keras: 2.2515 - r2_keras: 0.9976 - val_loss: 12.7262 - val_mean_squared_error: 10.4751 - val_mee_keras: 3.4177 - val_r2_keras: 0.9935
# Epoch 145/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.0233 - mean_squared_error: 3.7616 - mee_keras: 2.1902 - r2_keras: 0.9977 - val_loss: 12.8588 - val_mean_squared_error: 10.5990 - val_mee_keras: 3.5374 - val_r2_keras: 0.9935
# Epoch 146/30000
# 24/24 [==============================] - 0s 7ms/step - loss: 6.1408 - mean_squared_error: 3.8806 - mee_keras: 2.2207 - r2_keras: 0.9976 - val_loss: 11.3864 - val_mean_squared_error: 9.1257 - val_mee_keras: 3.3312 - val_r2_keras: 0.9943
# Epoch 147/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1137 - mean_squared_error: 3.8553 - mee_keras: 2.2169 - r2_keras: 0.9977 - val_loss: 11.3381 - val_mean_squared_error: 9.0756 - val_mee_keras: 3.2940 - val_r2_keras: 0.9943
# Epoch 148/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.0264 - mean_squared_error: 3.7635 - mee_keras: 2.1982 - r2_keras: 0.9977 - val_loss: 12.1458 - val_mean_squared_error: 9.8856 - val_mee_keras: 3.4464 - val_r2_keras: 0.9939
# Epoch 149/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.1486 - mean_squared_error: 3.8857 - mee_keras: 2.2280 - r2_keras: 0.9976 - val_loss: 14.8232 - val_mean_squared_error: 12.5638 - val_mee_keras: 3.8323 - val_r2_keras: 0.9923
# Epoch 150/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1566 - mean_squared_error: 3.8957 - mee_keras: 2.2040 - r2_keras: 0.9977 - val_loss: 10.8369 - val_mean_squared_error: 8.5778 - val_mee_keras: 3.2104 - val_r2_keras: 0.9946
# Epoch 151/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.0828 - mean_squared_error: 3.8255 - mee_keras: 2.1959 - r2_keras: 0.9977 - val_loss: 11.6747 - val_mean_squared_error: 9.4149 - val_mee_keras: 3.3646 - val_r2_keras: 0.9941
# Epoch 152/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.0208 - mean_squared_error: 3.7686 - mee_keras: 2.1836 - r2_keras: 0.9977 - val_loss: 13.6705 - val_mean_squared_error: 11.4216 - val_mee_keras: 3.5529 - val_r2_keras: 0.9930
# Epoch 153/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.0079 - mean_squared_error: 3.7549 - mee_keras: 2.2008 - r2_keras: 0.9977 - val_loss: 13.5909 - val_mean_squared_error: 11.3417 - val_mee_keras: 3.4662 - val_r2_keras: 0.9930
# Epoch 154/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.0677 - mean_squared_error: 3.8142 - mee_keras: 2.1967 - r2_keras: 0.9977 - val_loss: 11.5355 - val_mean_squared_error: 9.2767 - val_mee_keras: 3.3212 - val_r2_keras: 0.9942
# Epoch 155/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1422 - mean_squared_error: 3.8881 - mee_keras: 2.2036 - r2_keras: 0.9976 - val_loss: 12.0639 - val_mean_squared_error: 9.8046 - val_mee_keras: 3.4265 - val_r2_keras: 0.9938
# Epoch 156/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.2638 - mean_squared_error: 4.0125 - mee_keras: 2.2573 - r2_keras: 0.9976 - val_loss: 10.9126 - val_mean_squared_error: 8.6542 - val_mee_keras: 3.1935 - val_r2_keras: 0.9945
# Epoch 157/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1924 - mean_squared_error: 3.9347 - mee_keras: 2.2456 - r2_keras: 0.9976 - val_loss: 11.4489 - val_mean_squared_error: 9.1896 - val_mee_keras: 3.2323 - val_r2_keras: 0.9942
# Epoch 158/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 5.9905 - mean_squared_error: 3.7327 - mee_keras: 2.2073 - r2_keras: 0.9977 - val_loss: 10.9361 - val_mean_squared_error: 8.6765 - val_mee_keras: 3.1624 - val_r2_keras: 0.9945
# Epoch 159/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.0846 - mean_squared_error: 3.8294 - mee_keras: 2.1367 - r2_keras: 0.9977 - val_loss: 13.7265 - val_mean_squared_error: 11.4760 - val_mee_keras: 3.6244 - val_r2_keras: 0.9929
# Epoch 160/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.2010 - mean_squared_error: 3.9481 - mee_keras: 2.2604 - r2_keras: 0.9976 - val_loss: 12.7062 - val_mean_squared_error: 10.4604 - val_mee_keras: 3.4634 - val_r2_keras: 0.9936
# Epoch 161/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 5.9782 - mean_squared_error: 3.7241 - mee_keras: 2.1918 - r2_keras: 0.9977 - val_loss: 11.8726 - val_mean_squared_error: 9.6158 - val_mee_keras: 3.3027 - val_r2_keras: 0.9940
# Epoch 162/30000
# 24/24 [==============================] - 0s 10ms/step - loss: 6.2766 - mean_squared_error: 4.0209 - mee_keras: 2.2362 - r2_keras: 0.9976 - val_loss: 12.1152 - val_mean_squared_error: 9.8551 - val_mee_keras: 3.4925 - val_r2_keras: 0.9938
# Epoch 163/30000
# 24/24 [==============================] - 0s 10ms/step - loss: 6.0544 - mean_squared_error: 3.7947 - mee_keras: 2.2140 - r2_keras: 0.9977 - val_loss: 12.2888 - val_mean_squared_error: 10.0300 - val_mee_keras: 3.3658 - val_r2_keras: 0.9938
# Epoch 164/30000
# 24/24 [==============================] - 0s 10ms/step - loss: 5.9013 - mean_squared_error: 3.6415 - mee_keras: 2.1957 - r2_keras: 0.9978 - val_loss: 11.2851 - val_mean_squared_error: 9.0234 - val_mee_keras: 3.2859 - val_r2_keras: 0.9943
# Epoch 165/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.1035 - mean_squared_error: 3.8531 - mee_keras: 2.1835 - r2_keras: 0.9977 - val_loss: 11.2177 - val_mean_squared_error: 8.9661 - val_mee_keras: 3.2044 - val_r2_keras: 0.9944
# Epoch 166/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 5.9950 - mean_squared_error: 3.7491 - mee_keras: 2.1961 - r2_keras: 0.9977 - val_loss: 13.1565 - val_mean_squared_error: 10.9147 - val_mee_keras: 3.5894 - val_r2_keras: 0.9933
# Epoch 167/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1803 - mean_squared_error: 3.9341 - mee_keras: 2.2186 - r2_keras: 0.9976 - val_loss: 11.5651 - val_mean_squared_error: 9.3132 - val_mee_keras: 3.2517 - val_r2_keras: 0.9942
# Epoch 168/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 5.9337 - mean_squared_error: 3.6848 - mee_keras: 2.1667 - r2_keras: 0.9978 - val_loss: 12.5921 - val_mean_squared_error: 10.3456 - val_mee_keras: 3.5791 - val_r2_keras: 0.9936
# Epoch 169/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.0722 - mean_squared_error: 3.8276 - mee_keras: 2.1995 - r2_keras: 0.9977 - val_loss: 12.1797 - val_mean_squared_error: 9.9362 - val_mee_keras: 3.3654 - val_r2_keras: 0.9939
# Epoch 170/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.1026 - mean_squared_error: 3.8543 - mee_keras: 2.1863 - r2_keras: 0.9976 - val_loss: 11.3773 - val_mean_squared_error: 9.1277 - val_mee_keras: 3.2576 - val_r2_keras: 0.9943
# Epoch 171/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.0845 - mean_squared_error: 3.8354 - mee_keras: 2.2116 - r2_keras: 0.9977 - val_loss: 15.0553 - val_mean_squared_error: 12.8102 - val_mee_keras: 3.8287 - val_r2_keras: 0.9921
# Epoch 172/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 5.9461 - mean_squared_error: 3.6971 - mee_keras: 2.1813 - r2_keras: 0.9978 - val_loss: 11.3634 - val_mean_squared_error: 9.1113 - val_mee_keras: 3.3008 - val_r2_keras: 0.9942
# Epoch 173/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1636 - mean_squared_error: 3.9136 - mee_keras: 2.2474 - r2_keras: 0.9976 - val_loss: 11.4349 - val_mean_squared_error: 9.1818 - val_mee_keras: 3.3127 - val_r2_keras: 0.9942
# Epoch 174/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1916 - mean_squared_error: 3.9427 - mee_keras: 2.1938 - r2_keras: 0.9976 - val_loss: 11.4945 - val_mean_squared_error: 9.2459 - val_mee_keras: 3.3109 - val_r2_keras: 0.9943
# Epoch 175/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1503 - mean_squared_error: 3.8994 - mee_keras: 2.2379 - r2_keras: 0.9976 - val_loss: 11.5249 - val_mean_squared_error: 9.2660 - val_mee_keras: 3.2205 - val_r2_keras: 0.9942
# Epoch 176/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 5.9489 - mean_squared_error: 3.6957 - mee_keras: 2.1840 - r2_keras: 0.9978 - val_loss: 11.8336 - val_mean_squared_error: 9.5823 - val_mee_keras: 3.4044 - val_r2_keras: 0.9940
# Epoch 177/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.0901 - mean_squared_error: 3.8398 - mee_keras: 2.2111 - r2_keras: 0.9977 - val_loss: 12.1654 - val_mean_squared_error: 9.9156 - val_mee_keras: 3.4248 - val_r2_keras: 0.9939
# Epoch 178/30000
# 24/24 [==============================] - 0s 10ms/step - loss: 6.0881 - mean_squared_error: 3.8357 - mee_keras: 2.2033 - r2_keras: 0.9977 - val_loss: 11.1288 - val_mean_squared_error: 8.8690 - val_mee_keras: 3.2451 - val_r2_keras: 0.9944
# Epoch 179/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.0219 - mean_squared_error: 3.7649 - mee_keras: 2.1596 - r2_keras: 0.9977 - val_loss: 11.1015 - val_mean_squared_error: 8.8420 - val_mee_keras: 3.1669 - val_r2_keras: 0.9945
# Epoch 180/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 5.9408 - mean_squared_error: 3.6839 - mee_keras: 2.1595 - r2_keras: 0.9978 - val_loss: 11.3837 - val_mean_squared_error: 9.1257 - val_mee_keras: 3.2668 - val_r2_keras: 0.9943
# Epoch 181/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 5.8982 - mean_squared_error: 3.6488 - mee_keras: 2.1650 - r2_keras: 0.9978 - val_loss: 12.2157 - val_mean_squared_error: 9.9637 - val_mee_keras: 3.4844 - val_r2_keras: 0.9938
# Epoch 182/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.0154 - mean_squared_error: 3.7648 - mee_keras: 2.1899 - r2_keras: 0.9977 - val_loss: 13.3723 - val_mean_squared_error: 11.1258 - val_mee_keras: 3.4339 - val_r2_keras: 0.9931
# Epoch 183/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.0634 - mean_squared_error: 3.8152 - mee_keras: 2.1972 - r2_keras: 0.9977 - val_loss: 13.2462 - val_mean_squared_error: 10.9992 - val_mee_keras: 3.5140 - val_r2_keras: 0.9932
# Epoch 184/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1154 - mean_squared_error: 3.8673 - mee_keras: 2.1977 - r2_keras: 0.9976 - val_loss: 11.6806 - val_mean_squared_error: 9.4298 - val_mee_keras: 3.2667 - val_r2_keras: 0.9940
# Epoch 185/30000
# 24/24 [==============================] - 0s 9ms/step - loss: 6.0306 - mean_squared_error: 3.7849 - mee_keras: 2.1946 - r2_keras: 0.9977 - val_loss: 11.6656 - val_mean_squared_error: 9.4186 - val_mee_keras: 3.3124 - val_r2_keras: 0.9942
# Epoch 186/30000
# 24/24 [==============================] - 0s 8ms/step - loss: 6.1754 - mean_squared_error: 3.9266 - mee_keras: 2.2063 - r2_keras: 0.9976 - val_loss: 12.7502 - val_mean_squared_error: 10.4966 - val_mee_keras: 3.4465 - val_r2_keras: 0.9936

# %%
# Testing model performance on internal TS
X_test = df_subset[attributes].values
y_test = df_subset[['target_x', 'target_y']].values

TS_results = submodel.evaluate(X_test, y_test, verbose=1)

print('\n---------- Internal TS results ----------')
print(f'Loss: {TS_results[0]} - Metrics - MSE: {TS_results[1]} - MEE: {TS_results[2]} - R2: {TS_results[3]}\n\n\n')
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 9.0043 - mean_squared_error: 6.7825 - mee_keras: 3.0144 - r2_keras: 0.9959
#
# ---------- Internal TS results ----------
# Loss: 9.004262924194336 - Metrics - MSE: 6.782477855682373 - MEE: 3.0144479274749756 - R2: 0.9959160685539246

# %% [markdown]
# # Writing results of the blind test

# %%
# Prediction of values on blind TS
# predictions = L2_model.predict(df_test.values, verbose=0) -> For large scale inputs
predictions = model(df_test.values).numpy()
predictions
# Out:
# array([[ 41.888275 , -32.843224 ],
#        [ 67.21236  , -31.842903 ],
#        [ 78.03936  , -27.02604  ],
#        [ 34.29165  , -19.643425 ],
#        [ 66.48585  , -33.48648  ],
#        [ 50.65329  , -39.846474 ],
#        [ 53.12379  , -40.284874 ],
#        [ 51.243507 , -40.818954 ],
#        [ 36.38344  , -24.644863 ],
#        [ 75.279396 , -27.502129 ],
#        [ 30.800234 , -13.704215 ],
#        [ 36.361923 , -26.628857 ],
#        [ 29.231876 ,  -9.659461 ],
#        [ 46.1024   , -39.75016  ],
#        [ 72.9488   , -29.212402 ],
#        [ 44.634003 , -35.699886 ],
#        [ 62.951775 , -34.980114 ],
#        [ 38.96898  , -28.424805 ],
#        [ 76.56601  , -24.947273 ],
#        [ 31.150742 , -11.36602  ],
#        [ 75.92071  , -27.041794 ],
#        [ 45.56108  , -41.411015 ],
#        [ 39.41741  , -28.915531 ],
#        [ 38.39285  , -28.047852 ],
#        [ 74.99087  , -27.464485 ],
#        [ 57.989834 , -38.321808 ],
#        [ 72.66487  , -28.367584 ],
#        [ 31.522112 , -14.070361 ],
#        [ 75.229355 , -27.109184 ],
#        [ 33.37328  , -18.310509 ],
#        [ 56.844254 , -37.495926 ],
#        [ 55.55594  , -37.877853 ],
#        [ 30.586792 , -12.720435 ],
#        [ 60.934975 , -35.507805 ],
#        [ 32.545086 , -17.920046 ],
#        [ 70.29895  , -29.87954  ],
#        [ 65.68848  , -33.617798 ],
#        [ 60.424988 , -36.47548  ],
#        [ 31.642988 , -14.642941 ],
#        [ 73.65755  , -28.459068 ],
#        [ 62.49957  , -35.152992 ],
#        [ 49.284973 , -41.116314 ],
#        [ 30.008148 , -12.902418 ],
#        [ 37.607193 , -26.19823  ],
#        [ 31.481012 , -14.539775 ],
#        [ 65.82524  , -33.4977   ],
#        [ 60.61202  , -37.60756  ],
#        [ 66.65695  , -32.675934 ],
#        [ 73.25764  , -27.877018 ],
#        [ 45.84379  , -41.49164  ],
#        [ 38.548767 , -27.796417 ],
#        [ 40.50918  , -30.63594  ],
#        [ 78.16113  , -24.750576 ],
#        [ 30.32466  , -10.175392 ],
#        [ 35.13971  , -22.677525 ],
#        [ 72.55031  , -30.190517 ],
#        [ 71.50535  , -30.675755 ],
#        [ 43.5499   , -36.877846 ],
#        [ 32.66575  , -18.983894 ],
#        [ 55.815254 , -39.39383  ],
#        [ 55.944427 , -38.732304 ],
#        [ 32.19211  , -17.213554 ],
#        [ 45.64828  , -40.034073 ],
#        [ 74.27681  , -27.723644 ],
#        [ 33.592216 , -18.274591 ],
#        [ 38.57467  , -28.228878 ],
#        [ 34.822445 , -22.822067 ],
#        [ 37.419212 , -25.192825 ],
#        [ 57.992928 , -37.602554 ],
#        [ 76.97057  , -26.054176 ],
#        [ 32.530228 , -18.096504 ],
#        [ 45.971626 , -40.288837 ],
#        [ 30.37267  , -12.117076 ],
#        [ 67.81289  , -32.425884 ],
#        [ 45.78122  , -42.086834 ],
#        [ 66.619484 , -32.671593 ],
#        [ 48.315815 , -41.314445 ],
#        [ 26.296894 ,  -4.2004776],
#        [ 36.07007  , -24.508099 ],
#        [ 38.47288  , -28.045376 ],
#        [ 45.547066 , -39.53823  ],
#        [ 42.48148  , -34.01028  ],
#        [ 46.346127 , -40.98535  ],
#        [ 65.59557  , -33.687164 ],
#        [ 51.541325 , -40.961697 ],
#        [ 44.63518  , -38.26621  ],
#        [ 46.096786 , -40.459473 ],
#        [ 40.318024 , -29.649353 ],
#        [ 48.021126 , -40.73936  ],
#        [ 46.16793  , -41.2013   ],
#        [ 28.40061  ,  -7.7518783],
#        [ 49.424282 , -41.072308 ],
#        [ 28.800936 ,  -8.229593 ],
#        [ 28.102573 ,  -7.3177238],
#        [ 32.395702 , -17.274918 ],
#        [ 41.30856  , -32.04162  ],
#        [ 71.80394  , -28.041348 ],
#        [ 77.769    , -25.386364 ],
#        [ 58.68496  , -37.980637 ],
#        [ 33.921436 , -20.094967 ],
#        [ 75.431404 , -27.5225   ],
#        [ 51.82215  , -40.363106 ],
#        [ 48.96933  , -40.928684 ],
#        [ 45.690483 , -37.868534 ],
#        [ 34.558464 , -22.788307 ],
#        [ 30.947699 , -13.38874  ],
#        [ 34.83682  , -22.071404 ],
#        [ 74.94937  , -27.260574 ],
#        [ 43.810753 , -35.96801  ],
#        [ 43.785797 , -36.33625  ],
#        [ 46.293205 , -41.032074 ],
#        [ 50.958294 , -41.025368 ],
#        [ 45.827557 , -40.823433 ],
#        [ 56.7132   , -37.942696 ],
#        [ 39.859974 , -30.092045 ],
#        [ 63.754944 , -33.20009  ],
#        [ 39.39617  , -30.88047  ],
#        [ 63.843285 , -34.368828 ],
#        [ 43.036766 , -34.01788  ],
#        [ 56.29534  , -38.25688  ],
#        [ 33.75574  , -21.07896  ],
#        [ 47.2573   , -41.106762 ],
#        [ 37.97871  , -26.653053 ],
#        [ 46.49829  , -41.067078 ],
#        [ 43.785854 , -35.949463 ],
#        [ 75.46986  , -27.200005 ],
#        [ 66.59981  , -33.31519  ],
#        [ 38.835953 , -28.878738 ],
#        [ 55.835934 , -39.700237 ],
#        [ 38.45204  , -28.428268 ],
#        [ 72.09822  , -29.382221 ],
#        [ 36.485027 , -24.940975 ],
#        [ 50.08977  , -40.876877 ],
#        [ 28.062016 ,  -7.7191586],
#        [ 59.176743 , -37.756393 ],
#        [ 64.23803  , -34.64611  ],
#        [ 60.707794 , -35.45627  ],
#        [ 65.102646 , -33.35289  ],
#        [ 44.883884 , -38.09721  ],
#        [ 34.1941   , -20.19329  ],
#        [ 75.06306  , -27.13456  ],
#        [ 36.691277 , -24.685223 ],
#        [ 42.631786 , -34.196014 ],
#        [ 30.887684 , -12.754821 ],
#        [ 67.842155 , -31.51804  ],
#        [ 57.84651  , -38.59465  ],
#        [ 37.013973 , -26.573635 ],
#        [ 32.04636  , -15.902973 ],
#        [ 30.284132 , -11.261803 ],
#        [ 56.0176   , -39.92286  ],
#        [ 63.884727 , -33.47592  ],
#        [ 32.69691  , -18.069736 ],
#        [ 55.830532 , -38.49897  ],
#        [ 32.71778  , -16.656761 ],
#        [ 45.28486  , -40.080425 ],
#        [ 71.81116  , -29.670433 ],
#        [ 57.05353  , -37.671867 ],
#        [ 31.822624 , -16.41718  ],
#        [ 33.724785 , -20.77147  ],
#        [ 75.94887  , -26.496666 ],
#        [ 75.09683  , -26.807724 ],
#        [ 34.740685 , -23.683342 ],
#        [ 63.64125  , -33.084145 ],
#        [ 39.068954 , -28.486198 ],
#        [ 70.84648  , -29.536194 ],
#        [ 39.365967 , -28.068882 ],
#        [ 56.628628 , -38.726562 ],
#        [ 62.982067 , -35.128254 ],
#        [ 45.795853 , -40.471725 ],
#        [ 32.360107 , -17.598251 ],
#        [ 70.38734  , -29.889763 ],
#        [ 32.19506  , -18.16832  ],
#        [ 53.354675 , -40.211464 ],
#        [ 41.505844 , -32.039104 ],
#        [ 44.74964  , -38.024544 ],
#        [ 28.062016 ,  -7.7191586],
#        [ 45.628853 , -39.069645 ],
#        [ 46.05685  , -40.89672  ],
#        [ 54.912727 , -38.283897 ],
#        [ 73.69483  , -28.119205 ],
#        [ 55.93582  , -38.779263 ],
#        [ 67.82477  , -31.980103 ],
#        [ 45.910385 , -40.945118 ],
#        [ 73.75483  , -28.053593 ],
#        [ 66.72309  , -32.638077 ],
#        [ 56.580124 , -37.53144  ],
#        [ 31.812746 , -16.447853 ],
#        [ 75.15682  , -27.919636 ],
#        [ 41.38816  , -31.582153 ],
#        [ 43.204643 , -35.090397 ],
#        [ 71.287964 , -29.73869  ],
#        [ 64.0263   , -34.389664 ],
#        [ 32.92192  , -16.288204 ],
#        [ 31.468258 , -13.887164 ],
#        [ 32.439247 , -16.853142 ],
#        [ 36.928772 , -26.826126 ],
#        [ 59.683167 , -35.657837 ],
#        [ 45.236347 , -39.061825 ],
#        [ 33.36058  , -20.265686 ],
#        [ 74.64752  , -26.839226 ],
#        [ 29.937939 , -12.080067 ],
#        [ 33.987823 , -19.88979  ],
#        [ 67.1205   , -33.317863 ],
#        [ 43.673424 , -35.529057 ],
#        [ 36.951572 , -25.701687 ],
#        [ 38.868355 , -28.716583 ],
#        [ 32.975677 , -17.561914 ],
#        [ 31.489162 , -11.408589 ],
#        [ 66.88645  , -32.68466  ],
#        [ 62.29187  , -33.804073 ],
#        [ 28.8339   ,  -8.150857 ],
#        [ 34.219997 , -20.273956 ],
#        [ 51.484848 , -40.185997 ],
#        [ 45.912468 , -41.375683 ],
#        [ 32.589127 , -16.450943 ],
#        [ 37.08719  , -26.183987 ],
#        [ 40.00326  , -30.273243 ],
#        [ 33.73816  , -20.076172 ],
#        [ 27.800417 ,  -6.2995906],
#        [ 31.796951 , -16.688526 ],
#        [ 49.78641  , -40.88464  ],
#        [ 36.516464 , -26.883724 ],
#        [ 59.689903 , -37.604122 ],
#        [ 30.068817 , -10.411577 ],
#        [ 62.407005 , -35.205643 ],
#        [ 33.680244 , -18.032734 ],
#        [ 41.045532 , -31.352554 ],
#        [ 45.26346  , -39.236435 ],
#        [ 36.29937  , -24.448307 ],
#        [ 59.85972  , -33.15449  ],
#        [ 77.029205 , -25.484089 ],
#        [ 51.431374 , -38.384438 ],
#        [ 57.29483  , -37.83255  ],
#        [ 50.573906 , -41.093044 ],
#        [ 38.035233 , -26.970295 ],
#        [ 40.485832 , -30.255192 ],
#        [ 76.95304  , -25.98513  ],
#        [ 35.732544 , -24.224358 ],
#        [ 30.058825 , -10.904598 ],
#        [ 38.778522 , -28.750988 ],
#        [ 38.081078 , -28.63005  ],
#        [ 75.08696  , -26.796936 ],
#        [ 35.31062  , -24.265453 ],
#        [ 28.289017 ,  -8.960144 ],
#        [ 30.800234 , -13.704215 ],
#        [ 30.003235 , -10.684475 ],
#        [ 54.780075 , -39.289055 ],
#        [ 56.827583 , -37.949898 ],
#        [ 76.07666  , -25.928787 ],
#        [ 66.28796  , -33.66943  ],
#        [ 62.7542   , -33.576984 ],
#        [ 35.67534  , -22.013622 ],
#        [ 51.085564 , -41.454815 ],
#        [ 45.40792  , -41.03076  ],
#        [ 46.26359  , -40.95421  ],
#        [ 29.225567 , -10.44714  ],
#        [ 78.17897  , -25.31887  ],
#        [ 64.360405 , -34.174595 ],
#        [ 41.88527  , -33.445972 ],
#        [ 46.568657 , -42.003525 ],
#        [ 33.178783 , -17.139206 ],
#        [ 56.23002  , -38.44169  ],
#        [ 69.21578  , -30.918995 ],
#        [ 34.36664  , -20.564224 ],
#        [ 36.427307 , -24.535564 ],
#        [ 57.08437  , -37.645515 ],
#        [ 28.63251  ,  -9.009933 ],
#        [ 71.5352   , -29.756664 ],
#        [ 75.94591  , -25.859104 ],
#        [ 27.6093   ,  -6.5835114],
#        [ 61.462128 , -36.082733 ],
#        [ 77.13947  , -25.925243 ],
#        [ 53.081123 , -41.58935  ],
#        [ 67.37276  , -32.653465 ],
#        [ 34.816265 , -21.090569 ],
#        [ 53.702118 , -39.253105 ],
#        [ 55.501305 , -38.439285 ],
#        [ 30.959608 , -14.244866 ],
#        [ 75.61059  , -26.561432 ],
#        [ 73.6015   , -26.131271 ],
#        [ 77.26194  , -25.988564 ],
#        [ 64.54475  , -34.51946  ],
#        [ 47.91591  , -41.97425  ],
#        [ 75.015045 , -26.57629  ],
#        [ 48.276897 , -41.368294 ],
#        [ 29.268711 , -10.638082 ],
#        [ 35.229122 , -24.537128 ],
#        [ 45.587673 , -40.55207  ],
#        [ 76.632034 , -26.17194  ],
#        [ 30.996819 , -12.843114 ],
#        [ 49.0784   , -41.450916 ],
#        [ 72.18569  , -28.8597   ],
#        [ 62.415268 , -35.4544   ],
#        [ 51.110653 , -40.645008 ],
#        [ 32.425983 , -18.008858 ],
#        [ 32.939144 , -15.727859 ],
#        [ 53.12107  , -40.6581   ],
#        [ 46.182304 , -40.29655  ],
#        [ 73.41076  , -28.154648 ],
#        [ 43.687836 , -35.395718 ],
#        [ 32.41191  , -16.820156 ],
#        [ 34.29165  , -19.643425 ],
#        [ 31.403833 , -15.818602 ],
#        [ 44.717297 , -37.428173 ],
#        [ 61.66205  , -36.594055 ],
#        [ 34.420513 , -20.53532  ],
#        [ 43.933147 , -35.81743  ],
#        [ 65.90713  , -33.15178  ],
#        [ 30.645395 , -12.955089 ],
#        [ 70.591934 , -29.09129  ],
#        [ 45.39968  , -39.54418  ],
#        [ 41.357765 , -32.424698 ],
#        [ 51.753525 , -41.01537  ],
#        [ 32.308098 , -14.85664  ],
#        [ 52.154583 , -41.697823 ],
#        [ 30.474161 , -11.991628 ],
#        [ 38.977203 , -29.179054 ],
#        [ 31.352055 , -15.400245 ],
#        [ 56.79152  , -38.403885 ],
#        [ 38.335297 , -28.026855 ],
#        [ 45.79013  , -40.65872  ],
#        [ 45.505253 , -39.6874   ],
#        [ 50.038277 , -40.692703 ],
#        [ 69.40845  , -30.406998 ],
#        [ 62.96836  , -35.156185 ],
#        [ 39.709076 , -29.559856 ],
#        [ 31.977    , -16.267365 ],
#        [ 63.359665 , -34.524014 ],
#        [ 45.266285 , -38.118015 ],
#        [ 52.557053 , -39.37793  ],
#        [ 77.372536 , -26.2809   ],
#        [ 75.82617  , -26.387524 ],
#        [ 45.093315 , -37.9255   ],
#        [ 45.002377 , -38.50171  ],
#        [ 39.610447 , -28.704494 ],
#        [ 41.18136  , -31.139412 ],
#        [ 46.89173  , -39.37891  ],
#        [ 46.113106 , -41.110897 ],
#        [ 29.225567 , -10.44714  ],
#        [ 29.806164 , -10.741571 ],
#        [ 59.63604  , -36.972908 ],
#        [ 73.25487  , -28.247192 ],
#        [ 63.433666 , -34.01164  ],
#        [ 45.62526  , -41.184265 ],
#        [ 73.58731  , -28.440311 ],
#        [ 62.78258  , -35.36038  ],
#        [ 29.335644 , -11.154547 ],
#        [ 50.88741  , -41.143715 ],
#        [ 40.725956 , -30.781006 ],
#        [ 35.6408   , -21.791786 ],
#        [ 32.295753 , -14.325177 ],
#        [ 55.870262 , -37.80414  ],
#        [ 71.52478  , -29.787033 ],
#        [ 45.15513  , -39.91091  ],
#        [ 61.962646 , -35.644485 ],
#        [ 41.065643 , -31.727955 ],
#        [ 73.05495  , -28.588165 ],
#        [ 49.55327  , -40.959854 ],
#        [ 40.69626  , -30.442902 ],
#        [ 31.05917  , -14.097951 ],
#        [ 29.548458 , -10.094651 ],
#        [ 30.21549  , -11.688385 ],
#        [ 49.270878 , -41.115772 ],
#        [ 36.169807 , -24.180645 ],
#        [ 30.160873 , -10.714016 ],
#        [ 55.37867  , -39.010376 ],
#        [ 38.902958 , -27.621506 ],
#        [ 31.865482 , -16.301525 ],
#        [ 56.08864  , -38.784294 ],
#        [ 63.0208   , -34.465324 ],
#        [ 43.717308 , -35.667812 ],
#        [ 67.52429  , -31.515    ],
#        [ 37.966892 , -26.297924 ],
#        [ 35.32062  , -23.523903 ],
#        [ 31.67855  , -14.617751 ],
#        [ 63.489624 , -33.830723 ],
#        [ 29.886646 , -10.375416 ],
#        [ 37.774475 , -27.976685 ],
#        [ 48.23864  , -36.01165  ],
#        [ 68.32883  , -31.114414 ],
#        [ 35.63355  , -24.360264 ],
#        [ 27.912079 ,  -7.8430552],
#        [ 76.75455  , -25.725006 ],
#        [ 63.565914 , -33.649597 ],
#        [ 30.32466  , -10.175392 ],
#        [ 42.64991  , -33.789825 ],
#        [ 73.68064  , -27.270325 ],
#        [ 41.00111  , -30.855515 ],
#        [ 76.64484  , -25.941628 ],
#        [ 74.809814 , -27.55281  ],
#        [ 41.446243 , -32.01844  ],
#        [ 46.569016 , -41.761074 ],
#        [ 74.60002  , -27.554691 ],
#        [ 38.60115  , -27.69727  ],
#        [ 45.992664 , -41.194237 ],
#        [ 30.241617 , -11.594616 ],
#        [ 39.37932  , -28.906075 ],
#        [ 37.383804 , -27.25557  ],
#        [ 51.39037  , -41.519257 ],
#        [ 46.363884 , -40.341465 ],
#        [ 44.01817  , -34.823807 ],
#        [ 64.87631  , -33.912563 ],
#        [ 69.072914 , -30.479996 ],
#        [ 35.683064 , -23.008434 ],
#        [ 43.01587  , -34.438137 ],
#        [ 31.1003   , -13.55594  ],
#        [ 75.096985 , -26.312138 ],
#        [ 35.771442 , -25.123905 ],
#        [ 57.76157  , -37.104027 ],
#        [ 44.10345  , -34.684757 ],
#        [ 62.353214 , -35.296013 ],
#        [ 32.54935  , -16.637945 ],
#        [ 46.804436 , -42.714035 ],
#        [ 56.054874 , -38.298035 ],
#        [ 32.323605 , -18.133747 ],
#        [ 40.20587  , -30.772373 ],
#        [ 59.116993 , -35.37806  ],
#        [ 59.559013 , -35.82885  ],
#        [ 36.332367 , -24.006329 ],
#        [ 49.08658  , -39.206264 ],
#        [ 34.866962 , -20.702679 ],
#        [ 30.995901 , -13.89215  ],
#        [ 50.10036  , -40.777832 ],
#        [ 64.14946  , -33.6253   ],
#        [ 40.066628 , -30.739803 ],
#        [ 74.04521  , -28.232258 ],
#        [ 42.536507 , -34.412586 ],
#        [ 64.26368  , -34.6441   ],
#        [ 29.400755 , -11.4403515],
#        [ 66.9766   , -32.75904  ],
#        [ 74.55957  , -26.963531 ],
#        [ 57.020164 , -37.9784   ],
#        [ 65.81621  , -32.67065  ],
#        [ 69.74604  , -30.090523 ],
#        [ 32.567646 , -17.191025 ],
#        [ 58.516407 , -38.678833 ],
#        [ 71.46271  , -30.236336 ],
#        [ 71.92431  , -29.390812 ],
#        [ 31.026142 , -13.573784 ],
#        [ 63.085873 , -34.199303 ],
#        [ 64.45273  , -34.06136  ],
#        [ 74.855354 , -27.61029  ],
#        [ 39.87004  , -29.309662 ],
#        [ 36.61634  , -23.128685 ],
#        [ 33.724987 , -19.789635 ],
#        [ 31.494883 , -15.763158 ],
#        [ 66.021515 , -32.549847 ],
#        [ 37.7162   , -27.61929  ],
#        [ 45.490944 , -41.067577 ],
#        [ 31.99179  , -17.132378 ],
#        [ 52.422646 , -40.83368  ],
#        [ 29.268711 , -10.638082 ],
#        [ 34.878387 , -23.04763  ],
#        [ 29.237133 ,  -7.1320677],
#        [ 53.62386  , -41.043453 ],
#        [ 67.05545  , -32.954548 ],
#        [ 31.297062 , -16.370773 ],
#        [ 67.751076 , -31.640358 ],
#        [ 30.701359 , -12.974011 ],
#        [ 48.137768 , -40.222404 ],
#        [ 41.959717 , -32.75303  ],
#        [ 33.957523 , -17.988659 ],
#        [ 36.454353 , -24.914738 ],
#        [ 32.025093 , -17.503235 ],
#        [ 45.609226 , -41.100605 ],
#        [ 69.38292  , -31.28257  ],
#        [ 45.827103 , -40.43435  ],
#        [ 77.787125 , -25.353363 ],
#        [ 31.732292 , -15.994264 ],
#        [ 32.42023  , -17.499063 ],
#        [ 41.257126 , -31.398472 ],
#        [ 38.64527  , -26.624397 ]], dtype=float32)

# %%
df_test_results = pd.DataFrame(predictions, df_test.index)
#df_test_results.to_csv(path_or_buf="/content/drive/My Drive/Machine Learning Project/CUP/broken_brain_ML-CUP20-TS.csv", 
                       sep=',', header=False, index=True, index_label=df_test.index)
# Out:
#   File "<ipython-input-55-ab5319547615>", line 3
#     sep=',', header=False, index=True, index_label=df_test.index)
#     ^
# IndentationError: unexpected indent
